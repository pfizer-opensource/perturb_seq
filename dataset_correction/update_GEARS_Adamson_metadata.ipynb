# %%
import pandas as pd
import re
import scanpy as sc

from numpy import where
from pathlib import Path

# %% [markdown]
# # Purpose
# Adamson 2016 dataset as provided by the GEARS authors appears to have some inconsistencies compared to the source data provided by the Adamson et. al. authors via GEO (https://ftp.ncbi.nlm.nih.gov/geo/series/GSE90nnn/GSE90546/suppl/GSE90546_RAW.tar). This notebook matches the dataset provided by GEARS with the original GEO submission and updates any metadata as necessary.

# %%
DATA_DIR = Path('/work/shared/perturbseq_testing/data/adamson_2016')

# %% [markdown]
# ## Load GEARS data

# %%
gears = sc.read_h5ad(DATA_DIR.joinpath('perturb_processed.h5ad'))
gears
# Out:
# AnnData object with n_obs × n_vars = 68603 × 5060
#     obs: 'condition', 'cell_type', 'dose_val', 'control', 'condition_name'
#     var: 'gene_name'
#     uns: 'non_dropout_gene_idx', 'non_zeros_gene_idx', 'rank_genes_groups_cov_all', 'top_non_dropout_de_20', 'top_non_zero_de_20'

# %% [markdown]
# ### save the ordering of barcodes in .obs so that the fixed version can be sorted in the same order

# %%
gears_original_index = gears.obs.index
print(gears_original_index)
# Out:
# Index(['AAACATACACCGAT-1', 'AAACATACAGAGAT-1', 'AAACATACCAGAAA-1',
#        'AAACATACGTTGAC-1', 'AAACATACTGTTCT-1', 'AAACCGTGCAGCTA-1',
#        'AAACCGTGCCTGAA-1', 'AAACCGTGCGGAGA-1', 'AAACCGTGGAACTC-1',
#        'AAACGCACCATGGT-1',
#        ...
#        'TTTGACTGTACGAC-10', 'TTTGCATGAATCGC-10', 'TTTGCATGCACACA-10',
#        'TTTGCATGCCCGTT-10', 'TTTGCATGCCTATT-10', 'TTTGCATGCTTTAC-10',
#        'TTTGCATGGAGGAC-10', 'TTTGCATGTAGAGA-10', 'TTTGCATGTCAAGC-10',
#        'TTTGCATGTGGAGG-10'],
#       dtype='object', name='cell_barcode', length=68603)

# %%
gears.obs.index.is_unique
# Out:
# True

# %% [markdown]
# ## Load Adamson data (generate from NCBI GEO source for pilot, UPR, and epistasis experiments)

# %%
pilot = sc.read(DATA_DIR.joinpath('adamson_2016_pilot_from_source.h5ad'))
pilot
# Out:
# /apps/conda/moccir/envs/cellcap/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 5768 × 35635
#     obs: 'guide_identity', 'read_count', 'UMI_count', 'coverage', 'good_coverage', 'number_of_cells', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb'
#     var: 'ensembl_id', 'gene_symbol', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
upr = sc.read_h5ad(DATA_DIR.joinpath('adamson_2016_upr_from_source.h5ad'))
upr
# Out:
# /apps/conda/moccir/envs/cellcap/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 65337 × 32738
#     obs: 'guide_identity', 'read_count', 'UMI_count', 'coverage', 'good_coverage', 'number_of_cells', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb'
#     var: 'ensembl_id', 'gene_symbol', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
epistasis = sc.read(DATA_DIR.joinpath('adamson_2016_epistasis_from_source.h5ad'))
epistasis
# Out:
# /apps/conda/moccir/envs/cellcap/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 15006 × 32738
#     obs: 'guide_identity', 'read_count', 'UMI_count', 'coverage', 'good_coverage', 'number_of_cells', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb'
#     var: 'ensembl_id', 'gene_symbol', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %% [markdown]
# ## Mark barcode collisions that results from GEARS authors combining all 3 sub-experiments in Adamson 2016 into a single data object
# It appears from the GEARS AnnData object that they included all and then resolved duplicate indices resulting from the barcode collisions by using AnnData's make_unique functionality.

# %% [markdown]
# ### pilot/UPR collisions

# %%
pilot_upr_collisions = set(pilot.obs_names).intersection(set(upr.obs_names))
len(pilot_upr_collisions)
# Out:
# 46

# %% [markdown]
# ### pilot/epistasis collisions

# %%
pilot_epistasis_collisions = set(pilot.obs_names).intersection(set(epistasis.obs_names))
len(pilot_epistasis_collisions)
# Out:
# 53

# %% [markdown]
# ### UPR/epistasis collisions

# %%
upr_epistasis_collisions = set(upr.obs_names).intersection(set(epistasis.obs_names))
len(upr_epistasis_collisions)
# Out:
# 136

# %% [markdown]
# ### check for 3-way collisions within Adamson 2016

# %%
len(pilot_upr_collisions.intersection(upr_epistasis_collisions))
# Out:
# 0

# %% [markdown]
# ### total collisions within Adamson 2016 data

# %%
all_adamson_collisions = (pilot_upr_collisions.union(pilot_epistasis_collisions)).union(upr_epistasis_collisions)
len(all_adamson_collisions)
# Out:
# 235

# %% [markdown]
# ### how many of these are in GEARS?

# %%
adamson_collisions_in_gears = all_adamson_collisions.intersection(set(gears.obs.index))
len(adamson_collisions_in_gears)
# Out:
# 232

# %% [markdown]
# ### of the 232 in GEARS, are they all in there twice which would lead to 464 rows?

# %%
gears.obs[gears.obs.index.str.startswith(tuple(adamson_collisions_in_gears))].shape
# Out:
# (404, 5)

# %% [markdown]
# ### answer: no
# To move forward in understanding this, need to flag which rows in GEARS are actually coming from barcode collisions in Adamson. Define two additional columns: `potential_collision` meaning that the barcode is a collider in Adamson, but does not necessarily mean that both were taken by the GEARS authors, and `barcode_collision` defined as those that are actually still colliding within the GEARS version of Adamson.

# %%
gears.obs['potential_collision'] = gears.obs.index.str.startswith(tuple(adamson_collisions_in_gears))

# %% [markdown]
# ## Combine Adamson datasets into single object that includes a new column identifying the source experiment

# %%
pilot.obs['experiment'] = 'pilot'
upr.obs['experiment'] = 'upr'
epistasis.obs['experiment'] = 'epistasis'

adamson_all = sc.concat([pilot, upr, epistasis])
adamson_all
# Out:
# /apps/conda/moccir/envs/cellcap/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 86111 × 32738
#     obs: 'guide_identity', 'read_count', 'UMI_count', 'coverage', 'good_coverage', 'number_of_cells', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'experiment'

# %% [markdown]
# ## As expected there is a warning about non-unique obs_names resulting from the collisions
# Leave this alone for now because they will be resolved. Instead, use a regular expression to recreate the original barcode names before the collisions were made unique in the GEARS AnnData. Then merge the .obs dataframe into the GEARS .obs dataframe as a starting point for figuring out which Adamson experiment was the source for each cell in the duplicate pairs.

# %%
duplicated_barcodes = [barcode for barcode in gears.obs_names if re.match(r'[ACTG]{14}-\d-\d', barcode)]
print(f'Number of collisions: {len(duplicated_barcodes)}')
print(f'Examples of duplicated barcodes: {duplicated_barcodes[:10]}')
# Out:
# Number of collisions: 172
# Examples of duplicated barcodes: ['AAAGAGACTGCCAA-1-1', 'AATGTAACTTCTGT-1-1', 'ACAAGCACTGACTG-1-1', 'ACCCAAGAGACACT-1-1', 'ACGTGATGAGGCGA-1-1', 'AGAATACTCCACCT-1-1', 'AGACACACTATGCG-1-1', 'AGAGAAACTAGAAG-1-1', 'AGTCGCCTAACCGT-1-1', 'ATCACTTGGCCCTT-1-1']

# %% [markdown]
# The extra `-1` in these barcodes is the expected behavior of AnnData's `make_unique` functions

# %%
gears.obs['original_barcode'] = [barcode.rsplit('-', 1)[0] if re.match(r'[ACTG]{14}-\d-\d', barcode) else barcode for barcode in gears.obs_names]

# %%
gears.obs['barcode_collision'] = gears.obs['original_barcode'].duplicated(keep=False)
gears.obs['barcode_collision'].value_counts()
# Out:
# barcode_collision
# False    68259
# True       344
# Name: count, dtype: int64

# %% [markdown]
# Reminder: These 344 rows represent 344 cells arising from 172 collisions

# %%
gears.obs['potential_collision'].value_counts()
# Out:
# potential_collision
# False    68199
# True       404
# Name: count, dtype: int64

# %%
gears.obs.loc[gears.obs['potential_collision'], 'barcode_collision'].value_counts()
# Out:
# barcode_collision
# True     344
# False     60
# Name: count, dtype: int64

# %% [markdown]
# ### out of 404 potential collisions, 344 are coming from barcodes where both versions from Adamson made it into GEARS while 60 are coming from ones where only one of the pair from Adamson showed up in the GEARS version of their data
# A little arithmetic shows this all checks out:
# 235 barcode collisions in Adamson
# 232 of these barcodes appear in GEARS
# 344 are cases where both Adamson cells are there so divide by 2 and get 172
# 60 are cases where only one Adamson cell showed up
# 172 + 60 = 232 and this is equal to the number of colliding Adamson barcodes that appear in GEARS

# %%
combined_obs = gears.obs.merge(adamson_all.obs,
                               left_on='original_barcode',
                               right_index=True,
                               how='left',
                               suffixes=['_gears', '_adamson'])
combined_obs
# Out:
#                   condition_gears cell_type dose_val  control  \
# cell_barcode
# AAACATACACCGAT-1       CREB1+ctrl   K562(?)      1+1        0
# AAACATACAGAGAT-1             ctrl   K562(?)        1        1
# AAACATACCAGAAA-1             ctrl   K562(?)        1        1
# AAACATACGTTGAC-1             ctrl   K562(?)        1        1
# AAACATACTGTTCT-1             ctrl   K562(?)        1        1
# ...                           ...       ...      ...      ...
# TTTGCATGCTTTAC-10      STT3A+ctrl   K562(?)      1+1        0
# TTTGCATGGAGGAC-10   ARHGAP22+ctrl   K562(?)      1+1        0
# TTTGCATGTAGAGA-10            ctrl   K562(?)        1        1
# TTTGCATGTCAAGC-10     KCTD16+ctrl   K562(?)      1+1        0
# TTTGCATGTGGAGG-10     SAMM50+ctrl   K562(?)      1+1        0
#
#                               condition_name  potential_collision  \
# cell_barcode
# AAACATACACCGAT-1      K562(?)_CREB1+ctrl_1+1                False
# AAACATACAGAGAT-1              K562(?)_ctrl_1                False
# AAACATACCAGAAA-1              K562(?)_ctrl_1                False
# AAACATACGTTGAC-1              K562(?)_ctrl_1                False
# AAACATACTGTTCT-1              K562(?)_ctrl_1                False
# ...                                      ...                  ...
# TTTGCATGCTTTAC-10     K562(?)_STT3A+ctrl_1+1                False
# TTTGCATGGAGGAC-10  K562(?)_ARHGAP22+ctrl_1+1                False
# TTTGCATGTAGAGA-10             K562(?)_ctrl_1                False
# TTTGCATGTCAAGC-10    K562(?)_KCTD16+ctrl_1+1                False
# TTTGCATGTGGAGG-10    K562(?)_SAMM50+ctrl_1+1                False
#
#                     original_barcode  barcode_collision   guide_identity  \
# cell_barcode
# AAACATACACCGAT-1    AAACATACACCGAT-1              False     CREB1_pDS269
# AAACATACAGAGAT-1    AAACATACAGAGAT-1              False     SNAI1_pDS266
# AAACATACCAGAAA-1    AAACATACCAGAAA-1              False   62(mod)_pBA581
# AAACATACGTTGAC-1    AAACATACGTTGAC-1              False     EP300_pDS268
# AAACATACTGTTCT-1    AAACATACTGTTCT-1              False   62(mod)_pBA581
# ...                              ...                ...              ...
# TTTGCATGCTTTAC-10  TTTGCATGCTTTAC-10              False     STT3A_pDS011
# TTTGCATGGAGGAC-10  TTTGCATGGAGGAC-10              False  ARHGAP22_pDS458
# TTTGCATGTAGAGA-10  TTTGCATGTAGAGA-10              False   63(mod)_pBA580
# TTTGCATGTCAAGC-10  TTTGCATGTCAAGC-10              False    KCTD16_pDS096
# TTTGCATGTGGAGG-10  TTTGCATGTGGAGG-10              False    SAMM50_pDS156
#
#                    read_count  ...  total_counts_mt  log1p_total_counts_mt  \
# cell_barcode                   ...
# AAACATACACCGAT-1       1286.0  ...              0.0               0.000000
# AAACATACAGAGAT-1        296.0  ...              0.0               0.000000
# AAACATACCAGAAA-1       1829.0  ...              0.0               0.000000
# AAACATACGTTGAC-1       1580.0  ...              0.0               0.000000
# AAACATACTGTTCT-1        748.0  ...              0.0               0.000000
# ...                       ...  ...              ...                    ...
# TTTGCATGCTTTAC-10       476.0  ...            871.0               6.770790
# TTTGCATGGAGGAC-10       539.0  ...            539.0               6.291569
# TTTGCATGTAGAGA-10       647.0  ...           1203.0               7.093405
# TTTGCATGTCAAGC-10        98.0  ...           1056.0               6.963190
# TTTGCATGTGGAGG-10       427.0  ...            997.0               6.905753
#
#                    pct_counts_mt  total_counts_ribo log1p_total_counts_ribo  \
# cell_barcode
# AAACATACACCGAT-1        0.000000             2770.0                7.926963
# AAACATACAGAGAT-1        0.000000             3593.0                8.187021
# AAACATACCAGAAA-1        0.000000            11445.0                9.345396
# AAACATACGTTGAC-1        0.000000             3992.0                8.292298
# AAACATACTGTTCT-1        0.000000             3533.0                8.170186
# ...                          ...                ...                     ...
# TTTGCATGCTTTAC-10       5.996971             3294.0                8.100162
# TTTGCATGGAGGAC-10       4.612751             3153.0                8.056427
# TTTGCATGTAGAGA-10       7.242625             4353.0                8.378850
# TTTGCATGTCAAGC-10       7.296345             3004.0                8.008033
# TTTGCATGTGGAGG-10       5.919373             3385.0                8.127404
#
#                    pct_counts_ribo  total_counts_hb  log1p_total_counts_hb  \
# cell_barcode
# AAACATACACCGAT-1         34.037846             53.0               3.988984
# AAACATACAGAGAT-1         40.011135            121.0               4.804021
# AAACATACCAGAAA-1         40.003498            470.0               6.154858
# AAACATACGTTGAC-1         35.184204             53.0               3.988984
# AAACATACTGTTCT-1         35.817112            141.0               4.955827
# ...                            ...              ...                    ...
# TTTGCATGCTTTAC-10        22.679703            145.0               4.983607
# TTTGCATGGAGGAC-10        26.983313            135.0               4.912655
# TTTGCATGTAGAGA-10        26.207104            495.0               6.206576
# TTTGCATGTCAAGC-10        20.755890            319.0               5.768321
# TTTGCATGTGGAGG-10        20.097370            146.0               4.990433
#
#                    pct_counts_hb  experiment
# cell_barcode
# AAACATACACCGAT-1        0.651266       pilot
# AAACATACAGAGAT-1        1.347439       pilot
# AAACATACCAGAAA-1        1.642782       pilot
# AAACATACGTTGAC-1        0.467125       pilot
# AAACATACTGTTCT-1        1.429440       pilot
# ...                          ...         ...
# TTTGCATGCTTTAC-10       0.998348         upr
# TTTGCATGGAGGAC-10       1.155327         upr
# TTTGCATGTAGAGA-10       2.980132         upr
# TTTGCATGTCAAGC-10       2.204104         upr
# TTTGCATGTGGAGG-10       0.866829         upr
#
# [69007 rows x 33 columns]

# %% [markdown]
# ## GEARS calls control `ctrl` while `control` was used in Adamson so harmonize this to facilitate comparisons
# GEARS also added `+ctrl` to everything that was a single perturbation so that they could handle double perturbations. Use a lambda function to resolve both at the same time.

# %%
combined_obs['condition_gears_harmonized'] = combined_obs['condition_gears'].apply(lambda s: s.split('+ctrl')[0]).replace('ctrl', 'control')
combined_obs.loc[:, ['condition_gears_harmonized', 'condition_adamson']]
# Out:
# /tmp/ipykernel_3377724/3439925620.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   combined_obs['condition_gears_harmonized'] = combined_obs['condition_gears'].apply(lambda s: s.split('+ctrl')[0]).replace('ctrl', 'control')
#                   condition_gears_harmonized condition_adamson
# cell_barcode
# AAACATACACCGAT-1                       CREB1             CREB1
# AAACATACAGAGAT-1                     control             SNAI1
# AAACATACCAGAAA-1                     control           control
# AAACATACGTTGAC-1                     control             EP300
# AAACATACTGTTCT-1                     control           control
# ...                                      ...               ...
# TTTGCATGCTTTAC-10                      STT3A             STT3A
# TTTGCATGGAGGAC-10                   ARHGAP22          ARHGAP22
# TTTGCATGTAGAGA-10                    control           control
# TTTGCATGTCAAGC-10                     KCTD16            KCTD16
# TTTGCATGTGGAGG-10                     SAMM50            SAMM50
#
# [69007 rows x 2 columns]

# %% [markdown]
# ## Mark rows where GEARS condition agrees with the condition in the original source Adamson data

# %%
combined_obs['condition_agrees'] = (combined_obs['condition_gears_harmonized'].astype(str) == combined_obs['condition_adamson'].astype(str))
combined_obs['condition_agrees'].value_counts()
# Out:
# condition_agrees
# True     50610
# False    18397
# Name: count, dtype: int64

# %% [markdown]
# ### count potential_collisions with rows where condition agrees

# %%
combined_obs[combined_obs['potential_collision']].value_counts('condition_agrees')
# Out:
# condition_agrees
# False    594
# True     214
# Name: count, dtype: int64

# %% [markdown]
# ### count actual barcode_collisions with rows where condition agrees

# %%
combined_obs[combined_obs['barcode_collision']].value_counts('condition_agrees')
# Out:
# condition_agrees
# False    500
# True     188
# Name: count, dtype: int64

# %% [markdown]
# ### of the potential collisions where only one of the Adamson cells was included, how many agree on condition with the original Adamson annotation?

# %%
combined_obs[(combined_obs['potential_collision']) & (~combined_obs['barcode_collision'])].value_counts('condition_agrees')
# Out:
# condition_agrees
# False    94
# True     26
# Name: count, dtype: int64

# %% [markdown]
# ## It appears that GEARS authors also changed the condition of the epistasis data to `ctrl` even though most of these were actually doubly-perturbed cells
# Count how many of the disagreeing rows are from the epistasis data

# %%
combined_obs.loc[combined_obs['condition_agrees'] == False, 'experiment'].value_counts()
# Out:
# experiment
# epistasis    13647
# upr           2946
# pilot         1804
# Name: count, dtype: int64

# %%
18397 - 13647
# Out:
# 4750

# %%
combined_obs.loc[(combined_obs['potential_collision']) & (~combined_obs['barcode_collision']) & (combined_obs['condition_agrees'] == False), 'experiment'].value_counts()
# Out:
# experiment
# epistasis    48
# upr          38
# pilot         8
# Name: count, dtype: int64

# %% [markdown]
# ### For convenience and to make output more readable, create a shorter list of columns to display

# %%
columns_of_interest = ['original_barcode', 'condition_gears', 'condition_gears_harmonized', 'condition_adamson', 'condition_agrees', 'experiment']

# %% [markdown]
# ## Split combined_obs into rows with barcode collisions, potential collisions only, and fully unique barcodes (in Adamson) and initialize a columns of False values to mark which rows to keep in the ones with collisions (`keep`) and which rows have had their source cell from Adamson 2016 verified (`source_verified`)

# %%
combined_obs_unique = combined_obs.loc[(~combined_obs['barcode_collision']) & (~combined_obs['potential_collision'])].copy()
combined_obs_unique['keep'] = True
combined_obs_unique['source_verified'] = True
print(f'Unique dataframe shape: {combined_obs_unique.shape}')
# Out:
# Unique dataframe shape: (68199, 37)

# %%
combined_obs_barcode_collisions = combined_obs[combined_obs['barcode_collision']].copy()
print(f'Barcode collisions dataframe shape: {combined_obs_barcode_collisions.shape}')
combined_obs_barcode_collisions['keep'] = False
combined_obs_barcode_collisions['source_verified'] = False
combined_obs_barcode_collisions['keep'].value_counts()
# Out:
# Barcode collisions dataframe shape: (688, 35)
# keep
# False    688
# Name: count, dtype: int64

# %%
combined_obs_potential_collisions = combined_obs[(combined_obs['potential_collision']) & (~combined_obs['barcode_collision'])].copy()
print(f'Potential collisions dataframe shape: {combined_obs_potential_collisions.shape}')
combined_obs_potential_collisions['keep'] = False
combined_obs_potential_collisions['source_verified'] = False
combined_obs_potential_collisions['keep'].value_counts()
# Out:
# Potential collisions dataframe shape: (120, 35)
# keep
# False    120
# Name: count, dtype: int64

# %% [markdown]
# ### make sure row numbers of these new dataframes add up to the row number of the original dataframe

# %%
assert(combined_obs.shape[0] == (combined_obs_unique.shape[0] + combined_obs_barcode_collisions.shape[0] + combined_obs_potential_collisions.shape[0]))

# %% [markdown]
# ## Deal with actual barcode collisions first
# ### Grouping by the original barcode, count how many rows have conditions that agree between GEARS and Adamson
# There should be 4 rows per barcode because each barcode will match one cell each from two different Adamson data subsets (see above that there are no 3-way collisions within Adamson). Therefore, the possible values here should be 2 agree (i.e., it is fully resolvable), 1 agrees (i.e., it might be resolvable if it turns out the disagreeing one comes from epistasis and was incorrectly relabeled as control), and 0 agree (i.e., both have incorrect condition labels in GEARS and we cannot resolve which experiment each cell of the pair originally came from).

# %%
agreement_counts = (combined_obs_barcode_collisions
                        .groupby('original_barcode').aggregate(
                            count_agree=pd.NamedAgg(column="condition_agrees", aggfunc="sum"))
                   )
agreement_counts.value_counts()
# Out:
# count_agree
# 1              108
# 2               40
# 0               24
# Name: count, dtype: int64

# %% [markdown]
# ### simply for convenience and clarity of code, pull the barcodes in each of these categories into their own separate variables

# %%
agreement_2_barcodes = agreement_counts.index[agreement_counts['count_agree'] == 2]
print(f'2 agree barcodes: {len(agreement_2_barcodes)}')
agreement_1_barcodes = agreement_counts.index[agreement_counts['count_agree'] == 1]
print(f'1 agree barcodes: {len(agreement_1_barcodes)}')
agreement_0_barcodes = agreement_counts.index[agreement_counts['count_agree'] == 0]
print(f'0 agree barcodes: {len(agreement_0_barcodes)}')
# Out:
# 2 agree barcodes: 40
# 1 agree barcodes: 108
# 0 agree barcodes: 24

# %% [markdown]
# ## example of original barcode with 2 agreements

# %%
combined_obs[combined_obs['original_barcode'] == agreement_2_barcodes[0]][columns_of_interest]
# Out:
#                     original_barcode condition_gears  \
# cell_barcode
# AAATCCCTCTTGGA-1    AAATCCCTCTTGGA-1            ctrl
# AAATCCCTCTTGGA-1    AAATCCCTCTTGGA-1            ctrl
# AAATCCCTCTTGGA-1-1  AAATCCCTCTTGGA-1       DAD1+ctrl
# AAATCCCTCTTGGA-1-1  AAATCCCTCTTGGA-1       DAD1+ctrl
#
#                    condition_gears_harmonized condition_adamson  \
# cell_barcode
# AAATCCCTCTTGGA-1                      control           control
# AAATCCCTCTTGGA-1                      control              DAD1
# AAATCCCTCTTGGA-1-1                       DAD1           control
# AAATCCCTCTTGGA-1-1                       DAD1              DAD1
#
#                     condition_agrees experiment
# cell_barcode
# AAATCCCTCTTGGA-1                True      pilot
# AAATCCCTCTTGGA-1               False        upr
# AAATCCCTCTTGGA-1-1             False      pilot
# AAATCCCTCTTGGA-1-1              True        upr

# %% [markdown]
# ### If there are two rows that can be resolved, we can mark these to keep as the correct sources of the cells in GEARS, leaving the other two rows with the pre-initialized False value for `keep`
# It is possible to be tricked here if the 2 rows that agree are for the same original cell (e.g., if it had the same condition in both Adamson subsets and this condition matches what shows up in GEARS). It is unclear if this ever happens, but by making sure that the index is not duplicated for the ones marked as `keep` it can be shown that this did not happen.

# %%
combined_obs_barcode_collisions.loc[(combined_obs_barcode_collisions['original_barcode'].isin(agreement_2_barcodes)) & (combined_obs_barcode_collisions['condition_agrees'] == True), 'keep'] = True

combined_obs_barcode_collisions.loc[(combined_obs_barcode_collisions['original_barcode'].isin(agreement_2_barcodes)) & (combined_obs_barcode_collisions['condition_agrees'] == True), 'source_verified'] = True

# make sure duplicate rows aren't being marked as keep
assert(combined_obs_barcode_collisions[combined_obs_barcode_collisions['keep'] == True].index.is_unique)
print(f"Index is unique? {combined_obs_barcode_collisions[combined_obs_barcode_collisions['keep'] == True].index.is_unique}")
# Out:
# Index is unique? True

# %% [markdown]
# ## example of original barcode with 1 agreement

# %%
combined_obs[combined_obs['original_barcode'] == agreement_1_barcodes[0]][columns_of_interest]
# Out:
#                     original_barcode condition_gears  \
# cell_barcode
# AACACGTGGTACCA-2    AACACGTGGTACCA-2            ctrl
# AACACGTGGTACCA-2    AACACGTGGTACCA-2            ctrl
# AACACGTGGTACCA-2-1  AACACGTGGTACCA-2      YIPF5+ctrl
# AACACGTGGTACCA-2-1  AACACGTGGTACCA-2      YIPF5+ctrl
#
#                    condition_gears_harmonized condition_adamson  \
# cell_barcode
# AACACGTGGTACCA-2                      control             YIPF5
# AACACGTGGTACCA-2                      control         PERK_only
# AACACGTGGTACCA-2-1                      YIPF5             YIPF5
# AACACGTGGTACCA-2-1                      YIPF5         PERK_only
#
#                     condition_agrees experiment
# cell_barcode
# AACACGTGGTACCA-2               False        upr
# AACACGTGGTACCA-2               False  epistasis
# AACACGTGGTACCA-2-1              True        upr
# AACACGTGGTACCA-2-1             False  epistasis

# %%
combined_obs[combined_obs['original_barcode'].isin(agreement_1_barcodes)].value_counts('condition_agrees')
# Out:
# condition_agrees
# False    324
# True     108
# Name: count, dtype: int64

# %% [markdown]
# ### get the cell_barcode for the rows where there is agreement

# %%
agreement_1_resolved_barcodes = combined_obs_barcode_collisions[(combined_obs_barcode_collisions['original_barcode'].isin(agreement_1_barcodes)) & (combined_obs_barcode_collisions['condition_agrees'])].index
# how many?
print(len(agreement_1_resolved_barcodes))
# all unique?
print(len(set(agreement_1_resolved_barcodes)))
print(agreement_1_resolved_barcodes)
# Out:
# 108
# 108
# Index(['AATGTAACTTCTGT-1', 'ACGTGATGAGGCGA-1', 'AGACACACTATGCG-1',
#        'ATCACTTGGCCCTT-1', 'ATTGTCTGGCAGAG-1', 'CACTAACTCCTCGT-1',
#        'CCTAGAGAGGAAGC-1', 'CTACAACTGAGGGT-1', 'CTGATTTGAAGTAG-1',
#        'GGAGTTTGTTTCGT-1',
#        ...
#        'GAAACCTGCGTGTA-3-1', 'GAGATAGAGTATCG-3-1', 'GCCACGGAAACCAC-3-1',
#        'GGTATCGACCCAAA-3-1', 'TAATCCACGGCATT-3-1', 'TCATCAACATGACC-3-1',
#        'TGACACGAGCGATT-3-1', 'TGTAACCTCACCAA-3-1', 'TGTATCTGAACGTC-3-1',
#        'TTCAGTTGCGGGAA-3-1'],
#       dtype='object', name='cell_barcode', length=108)

# %% [markdown]
# ### of the cell_barcodes that are not resolved (i.e., the complement in the collision pair), how many of those came from epistasis where everything was incorrectly relabeled as control?

# %% [markdown]
# ### Helper function to check if any the unresolved cell of a collision pair with 1 agreement came from the epistasis experiment

# %%
def any_epistasis(s):
    result  = any([entry == 'epistasis' for entry in s])
    return result

# %%
agreement_1_unresolved_barcodes = combined_obs_barcode_collisions[combined_obs_barcode_collisions['original_barcode'].isin(agreement_1_barcodes)].index.difference(agreement_1_resolved_barcodes)
agreement_1_unresolved_epistasis = (combined_obs_barcode_collisions.loc[agreement_1_unresolved_barcodes]
     .groupby('cell_barcode')
     .aggregate(any_epistasis=pd.NamedAgg('experiment', any_epistasis))
                                   )
agreement_1_unresolved_epistasis.value_counts()
# Out:
# any_epistasis
# True             100
# False              8
# Name: count, dtype: int64

# %% [markdown]
# ### get these 100 barcodes, combine with the 108 resolved barcodes from above, and mark those rows as keep and source_verified

# %%
combined_obs_barcode_collisions.loc[(combined_obs_barcode_collisions.index.isin(agreement_1_resolved_barcodes)) & 
    (combined_obs_barcode_collisions['condition_agrees']), 'keep'] = True

combined_obs_barcode_collisions.loc[(combined_obs_barcode_collisions.index.isin(agreement_1_resolved_barcodes)) & 
    (combined_obs_barcode_collisions['condition_agrees']), 'source_verified'] = True

# make sure duplicate rows aren't being kept
assert(combined_obs_barcode_collisions[combined_obs_barcode_collisions['keep'] == True].index.is_unique)
print(f"Index is unique? {combined_obs_barcode_collisions[combined_obs_barcode_collisions['keep'] == True].index.is_unique}")
# Out:
# Index is unique? True

# %%
combined_obs_barcode_collisions.loc[(combined_obs_barcode_collisions.index.isin(agreement_1_unresolved_epistasis[agreement_1_unresolved_epistasis['any_epistasis']== True].index)) & 
    (combined_obs_barcode_collisions['experiment'] == 'epistasis'), 'keep'] = True

combined_obs_barcode_collisions.loc[(combined_obs_barcode_collisions.index.isin(agreement_1_unresolved_epistasis[agreement_1_unresolved_epistasis['any_epistasis']== True].index)) & 
    (combined_obs_barcode_collisions['experiment'] == 'epistasis'), 'source_verified'] = True

# make sure duplicate cells have not been added
assert(combined_obs_barcode_collisions[combined_obs_barcode_collisions['keep'] == True].index.is_unique)
print(f"Index is unique? {combined_obs_barcode_collisions[combined_obs_barcode_collisions['keep'] == True].index.is_unique}")
# Out:
# Index is unique? True

# %% [markdown]
# ### 8 should be remaining that should be kept but have the wrong labels

# %%
(combined_obs_barcode_collisions.loc[
     (combined_obs_barcode_collisions.index.isin(agreement_1_unresolved_epistasis[agreement_1_unresolved_epistasis['any_epistasis']== False].index))
     ][columns_of_interest + ['keep']]
)
# Out:
#                   original_barcode condition_gears condition_gears_harmonized  \
# cell_barcode
# ACAAGAGAACGTGT-1  ACAAGAGAACGTGT-1            ctrl                    control
# ACAAGAGAACGTGT-1  ACAAGAGAACGTGT-1            ctrl                    control
# AGAAAGTGGGTTTG-1  AGAAAGTGGGTTTG-1            ctrl                    control
# AGAAAGTGGGTTTG-1  AGAAAGTGGGTTTG-1            ctrl                    control
# CTGGCACTGTTCTT-1  CTGGCACTGTTCTT-1            ctrl                    control
# CTGGCACTGTTCTT-1  CTGGCACTGTTCTT-1            ctrl                    control
# GCACGGTGGTTTCT-1  GCACGGTGGTTTCT-1            ctrl                    control
# GCACGGTGGTTTCT-1  GCACGGTGGTTTCT-1            ctrl                    control
# GCGAAGGAGGAAAT-1  GCGAAGGAGGAAAT-1            ctrl                    control
# GCGAAGGAGGAAAT-1  GCGAAGGAGGAAAT-1            ctrl                    control
# GGCGACTGCAGTTG-1  GGCGACTGCAGTTG-1            ctrl                    control
# GGCGACTGCAGTTG-1  GGCGACTGCAGTTG-1            ctrl                    control
# TAAGAACTGCAGTT-1  TAAGAACTGCAGTT-1            ctrl                    control
# TAAGAACTGCAGTT-1  TAAGAACTGCAGTT-1            ctrl                    control
# TATCCAACTGCACA-1  TATCCAACTGCACA-1            ctrl                    control
# TATCCAACTGCACA-1  TATCCAACTGCACA-1            ctrl                    control
#
#                  condition_adamson  condition_agrees experiment   keep
# cell_barcode
# ACAAGAGAACGTGT-1             EP300             False      pilot  False
# ACAAGAGAACGTGT-1             DERL2             False        upr  False
# AGAAAGTGGGTTTG-1              SPI1             False      pilot  False
# AGAAAGTGGGTTTG-1              DARS             False        upr  False
# CTGGCACTGTTCTT-1             EP300             False      pilot  False
# CTGGCACTGTTCTT-1              FECH             False        upr  False
# GCACGGTGGTTTCT-1             SNAI1             False      pilot  False
# GCACGGTGGTTTCT-1            AMIGO3             False        upr  False
# GCGAAGGAGGAAAT-1             EP300             False      pilot  False
# GCGAAGGAGGAAAT-1              TARS             False        upr  False
# GGCGACTGCAGTTG-1             EP300             False      pilot  False
# GGCGACTGCAGTTG-1              XRN1             False        upr  False
# TAAGAACTGCAGTT-1              SPI1             False      pilot  False
# TAAGAACTGCAGTT-1            DDRGK1             False        upr  False
# TATCCAACTGCACA-1             SNAI1             False      pilot  False
# TATCCAACTGCACA-1              XRN1             False        upr  False

# %% [markdown]
# ### to know which of these is the cell that was actually taken from Adamson by the GEARS authors, need to consider which experiment the other member of the barcode collision pair came from and then this is the other one

# %%
(combined_obs_barcode_collisions[
    (combined_obs_barcode_collisions['original_barcode'].isin(agreement_1_unresolved_epistasis[agreement_1_unresolved_epistasis['any_epistasis']== False].index))
     ]
     .value_counts(['experiment', 'condition_agrees'])
)
# Out:
# experiment  condition_agrees
# pilot       False               16
# upr         False                8
#             True                 8
# Name: count, dtype: int64

# %% [markdown]
# ### in all cases it was from the UPR experiment, so the one to keep is the one from the pilot experiment

# %%
(combined_obs_barcode_collisions.loc[
     (combined_obs_barcode_collisions.index.isin(agreement_1_unresolved_epistasis[agreement_1_unresolved_epistasis['any_epistasis']== False].index)) &
     (combined_obs_barcode_collisions['experiment'] == 'pilot')
     ][columns_of_interest + ['keep']]
)
# Out:
#                   original_barcode condition_gears condition_gears_harmonized  \
# cell_barcode
# ACAAGAGAACGTGT-1  ACAAGAGAACGTGT-1            ctrl                    control
# AGAAAGTGGGTTTG-1  AGAAAGTGGGTTTG-1            ctrl                    control
# CTGGCACTGTTCTT-1  CTGGCACTGTTCTT-1            ctrl                    control
# GCACGGTGGTTTCT-1  GCACGGTGGTTTCT-1            ctrl                    control
# GCGAAGGAGGAAAT-1  GCGAAGGAGGAAAT-1            ctrl                    control
# GGCGACTGCAGTTG-1  GGCGACTGCAGTTG-1            ctrl                    control
# TAAGAACTGCAGTT-1  TAAGAACTGCAGTT-1            ctrl                    control
# TATCCAACTGCACA-1  TATCCAACTGCACA-1            ctrl                    control
#
#                  condition_adamson  condition_agrees experiment   keep
# cell_barcode
# ACAAGAGAACGTGT-1             EP300             False      pilot  False
# AGAAAGTGGGTTTG-1              SPI1             False      pilot  False
# CTGGCACTGTTCTT-1             EP300             False      pilot  False
# GCACGGTGGTTTCT-1             SNAI1             False      pilot  False
# GCGAAGGAGGAAAT-1             EP300             False      pilot  False
# GGCGACTGCAGTTG-1             EP300             False      pilot  False
# TAAGAACTGCAGTT-1              SPI1             False      pilot  False
# TATCCAACTGCACA-1             SNAI1             False      pilot  False

# %%
combined_obs_barcode_collisions.loc[
    (combined_obs_barcode_collisions.index.isin(agreement_1_unresolved_epistasis[agreement_1_unresolved_epistasis['any_epistasis']== False].index)) &
    (combined_obs_barcode_collisions['experiment'] == 'pilot'),
    'keep'] = True

combined_obs_barcode_collisions.loc[
    (combined_obs_barcode_collisions.index.isin(agreement_1_unresolved_epistasis[agreement_1_unresolved_epistasis['any_epistasis']== False].index)) &
    (combined_obs_barcode_collisions['experiment'] == 'pilot'),
    'source_verified'] = True

# make sure duplicate rows aren't being kept
assert(combined_obs_barcode_collisions[combined_obs_barcode_collisions['keep'] == True].index.is_unique)
print(f"Index is unique? {combined_obs_barcode_collisions[combined_obs_barcode_collisions['keep'] == True].index.is_unique}")
# Out:
# Index is unique? True

# %% [markdown]
# ## examine all sets of original barcodes with 0 agreements

# %%
for barcode in agreement_counts.index[agreement_counts['count_agree'] == 0]:
    print(barcode)
    print(combined_obs_barcode_collisions[combined_obs_barcode_collisions['original_barcode'] == barcode][['condition_gears_harmonized', 'condition_adamson', 'experiment']])
    print()
# Out:
# AAAGAGACTGCCAA-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# AAAGAGACTGCCAA-1                      control              SPI1      pilot
# AAAGAGACTGCCAA-1                      control         IRE1_only  epistasis
# AAAGAGACTGCCAA-1-1                    control              SPI1      pilot
# AAAGAGACTGCCAA-1-1                    control         IRE1_only  epistasis
#
# ACAAGCACTGACTG-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# ACAAGCACTGACTG-1                      control             EP300      pilot
# ACAAGCACTGACTG-1                      control       3x_neg_ctrl  epistasis
# ACAAGCACTGACTG-1-1                    control             EP300      pilot
# ACAAGCACTGACTG-1-1                    control       3x_neg_ctrl  epistasis
#
# AGAATACTCCACCT-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# AGAATACTCCACCT-1                      control             EP300      pilot
# AGAATACTCCACCT-1                      control         ATF6_IRE1  epistasis
# AGAATACTCCACCT-1-1                    control             EP300      pilot
# AGAATACTCCACCT-1-1                    control         ATF6_IRE1  epistasis
#
# AGAGAAACTAGAAG-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# AGAGAAACTAGAAG-1                      control              SPI1      pilot
# AGAGAAACTAGAAG-1                      control         ATF6_PERK  epistasis
# AGAGAAACTAGAAG-1-1                    control              SPI1      pilot
# AGAGAAACTAGAAG-1-1                    control         ATF6_PERK  epistasis
#
# ATTAGTGAGCTGTA-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# ATTAGTGAGCTGTA-1                      control             EP300      pilot
# ATTAGTGAGCTGTA-1                      control       3x_neg_ctrl  epistasis
# ATTAGTGAGCTGTA-1-1                    control             EP300      pilot
# ATTAGTGAGCTGTA-1-1                    control       3x_neg_ctrl  epistasis
#
# CACAATCTTCAGAC-2
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# CACAATCTTCAGAC-2                      control           DNAJC19        upr
# CACAATCTTCAGAC-2                      control         PERK_IRE1  epistasis
# CACAATCTTCAGAC-2-1                    control           DNAJC19        upr
# CACAATCTTCAGAC-2-1                    control         PERK_IRE1  epistasis
#
# CCACTTCTACTTTC-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# CCACTTCTACTTTC-1                      control             SNAI1      pilot
# CCACTTCTACTTTC-1                      control         ATF6_PERK  epistasis
# CCACTTCTACTTTC-1-1                    control             SNAI1      pilot
# CCACTTCTACTTTC-1-1                    control         ATF6_PERK  epistasis
#
# CGAGGAGACATTTC-3
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# CGAGGAGACATTTC-3                      control           DNAJC19        upr
# CGAGGAGACATTTC-3                      control         ATF6_only  epistasis
# CGAGGAGACATTTC-3-1                    control           DNAJC19        upr
# CGAGGAGACATTTC-3-1                    control         ATF6_only  epistasis
#
# CGAGGAGACTACGA-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# CGAGGAGACTACGA-1                      control            SEC61B        upr
# CGAGGAGACTACGA-1                      control         ATF6_PERK  epistasis
# CGAGGAGACTACGA-1-1                    control            SEC61B        upr
# CGAGGAGACTACGA-1-1                    control         ATF6_PERK  epistasis
#
# CGTAGCCTTTTACC-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# CGTAGCCTTTTACC-1                      control              SPI1      pilot
# CGTAGCCTTTTACC-1                      control         ATF6_IRE1  epistasis
# CGTAGCCTTTTACC-1-1                    control              SPI1      pilot
# CGTAGCCTTTTACC-1-1                    control         ATF6_IRE1  epistasis
#
# GCAGTCCTCATGCA-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# GCAGTCCTCATGCA-1                      control             EP300      pilot
# GCAGTCCTCATGCA-1                      control             ASCC3        upr
# GCAGTCCTCATGCA-1-1                    control             EP300      pilot
# GCAGTCCTCATGCA-1-1                    control             ASCC3        upr
#
# GCGAGAGACTGTAG-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# GCGAGAGACTGTAG-1                      control             EP300      pilot
# GCGAGAGACTGTAG-1                      control         PERK_IRE1  epistasis
# GCGAGAGACTGTAG-1-1                    control             EP300      pilot
# GCGAGAGACTGTAG-1-1                    control         PERK_IRE1  epistasis
#
# GGACCCGAACCCTC-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# GGACCCGAACCCTC-1                      control              SPI1      pilot
# GGACCCGAACCCTC-1                      control         ATF6_IRE1  epistasis
# GGACCCGAACCCTC-1-1                    control              SPI1      pilot
# GGACCCGAACCCTC-1-1                    control         ATF6_IRE1  epistasis
#
# GGCACGTGAGAAGT-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# GGCACGTGAGAAGT-1                      control             SNAI1      pilot
# GGCACGTGAGAAGT-1                      control         ATF6_only  epistasis
# GGCACGTGAGAAGT-1-1                    control             SNAI1      pilot
# GGCACGTGAGAAGT-1-1                    control         ATF6_only  epistasis
#
# GGGAAGTGGCTACA-2
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# GGGAAGTGGCTACA-2                      control            SEC61B        upr
# GGGAAGTGGCTACA-2                      control         ATF6_only  epistasis
# GGGAAGTGGCTACA-2-1                    control            SEC61B        upr
# GGGAAGTGGCTACA-2-1                    control         ATF6_only  epistasis
#
# GGGCAAGAGAGAGC-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# GGGCAAGAGAGAGC-1                      control             EP300      pilot
# GGGCAAGAGAGAGC-1                      control         IRE1_only  epistasis
# GGGCAAGAGAGAGC-1-1                    control             EP300      pilot
# GGGCAAGAGAGAGC-1-1                    control         IRE1_only  epistasis
#
# GGGCCATGCGAGAG-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# GGGCCATGCGAGAG-1                      control             SNAI1      pilot
# GGGCCATGCGAGAG-1                      control    ATF6_PERK_IRE1  epistasis
# GGGCCATGCGAGAG-1-1                    control             SNAI1      pilot
# GGGCCATGCGAGAG-1-1                    control    ATF6_PERK_IRE1  epistasis
#
# GTAGCAACTCATTC-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# GTAGCAACTCATTC-1                      control             EP300      pilot
# GTAGCAACTCATTC-1                      control    ATF6_PERK_IRE1  epistasis
# GTAGCAACTCATTC-1-1                    control             EP300      pilot
# GTAGCAACTCATTC-1-1                    control    ATF6_PERK_IRE1  epistasis
#
# TACCATTGTTTACC-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# TACCATTGTTTACC-1                      control             SNAI1      pilot
# TACCATTGTTTACC-1                      control       3x_neg_ctrl  epistasis
# TACCATTGTTTACC-1-1                    control             SNAI1      pilot
# TACCATTGTTTACC-1-1                    control       3x_neg_ctrl  epistasis
#
# TATAGCCTTCTCGC-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# TATAGCCTTCTCGC-1                      control           DNAJC19        upr
# TATAGCCTTCTCGC-1                      control         ATF6_IRE1  epistasis
# TATAGCCTTCTCGC-1-1                    control           DNAJC19        upr
# TATAGCCTTCTCGC-1-1                    control         ATF6_IRE1  epistasis
#
# TATCTGACACCACA-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# TATCTGACACCACA-1                      control             EP300      pilot
# TATCTGACACCACA-1                      control         ATF6_only  epistasis
# TATCTGACACCACA-1-1                    control             EP300      pilot
# TATCTGACACCACA-1-1                    control         ATF6_only  epistasis
#
# TGCGAAACTGCGTA-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# TGCGAAACTGCGTA-1                      control             SNAI1      pilot
# TGCGAAACTGCGTA-1                      control         ATF6_only  epistasis
# TGCGAAACTGCGTA-1-1                    control             SNAI1      pilot
# TGCGAAACTGCGTA-1-1                    control         ATF6_only  epistasis
#
# TGGTAGACGCTAAC-1
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# TGGTAGACGCTAAC-1                      control              SPI1      pilot
# TGGTAGACGCTAAC-1                      control    ATF6_PERK_IRE1  epistasis
# TGGTAGACGCTAAC-1-1                    control              SPI1      pilot
# TGGTAGACGCTAAC-1-1                    control    ATF6_PERK_IRE1  epistasis
#
# TGTGAGACTGAAGA-2
#                    condition_gears_harmonized condition_adamson experiment
# cell_barcode
# TGTGAGACTGAAGA-2                      control             ASCC3        upr
# TGTGAGACTGAAGA-2                      control    ATF6_PERK_IRE1  epistasis
# TGTGAGACTGAAGA-2-1                    control             ASCC3        upr
# TGTGAGACTGAAGA-2-1                    control    ATF6_PERK_IRE1  epistasis

# %% [markdown]
# ### these all appear to be incorrect
# Even the one case where the cell from epistasis really was a control (ATTAGTGAGCTGTA-1), this isn't believeable because in all cases but one, there is a possible cell from epistasis that is mislabeled as control. Therefore, it could just be a coincidence that it was labeled control and it will not be trusted here.
#
# Even more interestingly, there is one example (GCAGTCCTCATGCA-1) where the cells from Adamson with those barcodes came from pilot and UPR, with neither from epistasis. It is unclear why this, as well as the other of the collision pairs in the rest of these examples, are mislabeled as control in GEARS.

# %% [markdown]
# ### to resolve this, collapse the options from Adamson down to a delimited string providing the options, keep those rows, and mark source_verified as False

# %%
agg = dict.fromkeys(combined_obs_barcode_collisions.columns.difference(['condition_adamson', 'experiment']), 'first')
agg['condition_adamson'] = lambda s: '|'.join(s)
agg['experiment'] = lambda s: '|'.join(s)

agreement_0_replacement_rows = (combined_obs_barcode_collisions[
     combined_obs_barcode_collisions['original_barcode'].isin(agreement_counts.index[agreement_counts['count_agree'] == 0])]
     .groupby('cell_barcode')
     .agg(agg)
)
agreement_0_replacement_rows['keep'] = True
agreement_0_replacement_rows['source_verified'] = False
agreement_0_replacement_rows
# Out:
#                     UMI_count  barcode_collision cell_type  condition_agrees  \
# cell_barcode
# AAAGAGACTGCCAA-1         50.0               True   K562(?)             False
# AAAGAGACTGCCAA-1-1       50.0               True   K562(?)             False
# ACAAGCACTGACTG-1         71.0               True   K562(?)             False
# ACAAGCACTGACTG-1-1       71.0               True   K562(?)             False
# AGAATACTCCACCT-1        179.0               True   K562(?)             False
# AGAATACTCCACCT-1-1      179.0               True   K562(?)             False
# AGAGAAACTAGAAG-1         38.0               True   K562(?)             False
# AGAGAAACTAGAAG-1-1       38.0               True   K562(?)             False
# ATTAGTGAGCTGTA-1        116.0               True   K562(?)             False
# ATTAGTGAGCTGTA-1-1      116.0               True   K562(?)             False
# CACAATCTTCAGAC-2         30.0               True   K562(?)             False
# CACAATCTTCAGAC-2-1       30.0               True   K562(?)             False
# CCACTTCTACTTTC-1         48.0               True   K562(?)             False
# CCACTTCTACTTTC-1-1       48.0               True   K562(?)             False
# CGAGGAGACATTTC-3         35.0               True   K562(?)             False
# CGAGGAGACATTTC-3-1       35.0               True   K562(?)             False
# CGAGGAGACTACGA-1         11.0               True   K562(?)             False
# CGAGGAGACTACGA-1-1       11.0               True   K562(?)             False
# CGTAGCCTTTTACC-1         43.0               True   K562(?)             False
# CGTAGCCTTTTACC-1-1       43.0               True   K562(?)             False
# GCAGTCCTCATGCA-1         53.0               True   K562(?)             False
# GCAGTCCTCATGCA-1-1       53.0               True   K562(?)             False
# GCGAGAGACTGTAG-1         41.0               True   K562(?)             False
# GCGAGAGACTGTAG-1-1       41.0               True   K562(?)             False
# GGACCCGAACCCTC-1         48.0               True   K562(?)             False
# GGACCCGAACCCTC-1-1       48.0               True   K562(?)             False
# GGCACGTGAGAAGT-1         18.0               True   K562(?)             False
# GGCACGTGAGAAGT-1-1       18.0               True   K562(?)             False
# GGGAAGTGGCTACA-2         19.0               True   K562(?)             False
# GGGAAGTGGCTACA-2-1       19.0               True   K562(?)             False
# GGGCAAGAGAGAGC-1         35.0               True   K562(?)             False
# GGGCAAGAGAGAGC-1-1       35.0               True   K562(?)             False
# GGGCCATGCGAGAG-1         45.0               True   K562(?)             False
# GGGCCATGCGAGAG-1-1       45.0               True   K562(?)             False
# GTAGCAACTCATTC-1         83.0               True   K562(?)             False
# GTAGCAACTCATTC-1-1       83.0               True   K562(?)             False
# TACCATTGTTTACC-1         39.0               True   K562(?)             False
# TACCATTGTTTACC-1-1       39.0               True   K562(?)             False
# TATAGCCTTCTCGC-1         38.0               True   K562(?)             False
# TATAGCCTTCTCGC-1-1       38.0               True   K562(?)             False
# TATCTGACACCACA-1         74.0               True   K562(?)             False
# TATCTGACACCACA-1-1       74.0               True   K562(?)             False
# TGCGAAACTGCGTA-1         30.0               True   K562(?)             False
# TGCGAAACTGCGTA-1-1       30.0               True   K562(?)             False
# TGGTAGACGCTAAC-1         53.0               True   K562(?)             False
# TGGTAGACGCTAAC-1-1       53.0               True   K562(?)             False
# TGTGAGACTGAAGA-2         11.0               True   K562(?)             False
# TGTGAGACTGAAGA-2-1       11.0               True   K562(?)             False
#
#                    condition_gears condition_gears_harmonized  condition_name  \
# cell_barcode
# AAAGAGACTGCCAA-1              ctrl                    control  K562(?)_ctrl_1
# AAAGAGACTGCCAA-1-1            ctrl                    control  K562(?)_ctrl_1
# ACAAGCACTGACTG-1              ctrl                    control  K562(?)_ctrl_1
# ACAAGCACTGACTG-1-1            ctrl                    control  K562(?)_ctrl_1
# AGAATACTCCACCT-1              ctrl                    control  K562(?)_ctrl_1
# AGAATACTCCACCT-1-1            ctrl                    control  K562(?)_ctrl_1
# AGAGAAACTAGAAG-1              ctrl                    control  K562(?)_ctrl_1
# AGAGAAACTAGAAG-1-1            ctrl                    control  K562(?)_ctrl_1
# ATTAGTGAGCTGTA-1              ctrl                    control  K562(?)_ctrl_1
# ATTAGTGAGCTGTA-1-1            ctrl                    control  K562(?)_ctrl_1
# CACAATCTTCAGAC-2              ctrl                    control  K562(?)_ctrl_1
# CACAATCTTCAGAC-2-1            ctrl                    control  K562(?)_ctrl_1
# CCACTTCTACTTTC-1              ctrl                    control  K562(?)_ctrl_1
# CCACTTCTACTTTC-1-1            ctrl                    control  K562(?)_ctrl_1
# CGAGGAGACATTTC-3              ctrl                    control  K562(?)_ctrl_1
# CGAGGAGACATTTC-3-1            ctrl                    control  K562(?)_ctrl_1
# CGAGGAGACTACGA-1              ctrl                    control  K562(?)_ctrl_1
# CGAGGAGACTACGA-1-1            ctrl                    control  K562(?)_ctrl_1
# CGTAGCCTTTTACC-1              ctrl                    control  K562(?)_ctrl_1
# CGTAGCCTTTTACC-1-1            ctrl                    control  K562(?)_ctrl_1
# GCAGTCCTCATGCA-1              ctrl                    control  K562(?)_ctrl_1
# GCAGTCCTCATGCA-1-1            ctrl                    control  K562(?)_ctrl_1
# GCGAGAGACTGTAG-1              ctrl                    control  K562(?)_ctrl_1
# GCGAGAGACTGTAG-1-1            ctrl                    control  K562(?)_ctrl_1
# GGACCCGAACCCTC-1              ctrl                    control  K562(?)_ctrl_1
# GGACCCGAACCCTC-1-1            ctrl                    control  K562(?)_ctrl_1
# GGCACGTGAGAAGT-1              ctrl                    control  K562(?)_ctrl_1
# GGCACGTGAGAAGT-1-1            ctrl                    control  K562(?)_ctrl_1
# GGGAAGTGGCTACA-2              ctrl                    control  K562(?)_ctrl_1
# GGGAAGTGGCTACA-2-1            ctrl                    control  K562(?)_ctrl_1
# GGGCAAGAGAGAGC-1              ctrl                    control  K562(?)_ctrl_1
# GGGCAAGAGAGAGC-1-1            ctrl                    control  K562(?)_ctrl_1
# GGGCCATGCGAGAG-1              ctrl                    control  K562(?)_ctrl_1
# GGGCCATGCGAGAG-1-1            ctrl                    control  K562(?)_ctrl_1
# GTAGCAACTCATTC-1              ctrl                    control  K562(?)_ctrl_1
# GTAGCAACTCATTC-1-1            ctrl                    control  K562(?)_ctrl_1
# TACCATTGTTTACC-1              ctrl                    control  K562(?)_ctrl_1
# TACCATTGTTTACC-1-1            ctrl                    control  K562(?)_ctrl_1
# TATAGCCTTCTCGC-1              ctrl                    control  K562(?)_ctrl_1
# TATAGCCTTCTCGC-1-1            ctrl                    control  K562(?)_ctrl_1
# TATCTGACACCACA-1              ctrl                    control  K562(?)_ctrl_1
# TATCTGACACCACA-1-1            ctrl                    control  K562(?)_ctrl_1
# TGCGAAACTGCGTA-1              ctrl                    control  K562(?)_ctrl_1
# TGCGAAACTGCGTA-1-1            ctrl                    control  K562(?)_ctrl_1
# TGGTAGACGCTAAC-1              ctrl                    control  K562(?)_ctrl_1
# TGGTAGACGCTAAC-1-1            ctrl                    control  K562(?)_ctrl_1
# TGTGAGACTGAAGA-2              ctrl                    control  K562(?)_ctrl_1
# TGTGAGACTGAAGA-2-1            ctrl                    control  K562(?)_ctrl_1
#
#                     control   coverage dose_val  ...  pct_counts_ribo  \
# cell_barcode                                     ...
# AAAGAGACTGCCAA-1          1  13.740000        1  ...        37.997589
# AAAGAGACTGCCAA-1-1        1  13.740000        1  ...        37.997589
# ACAAGCACTGACTG-1          1  14.732394        1  ...        38.726486
# ACAAGCACTGACTG-1-1        1  14.732394        1  ...        38.726486
# AGAATACTCCACCT-1          1  15.469274        1  ...        41.632729
# AGAATACTCCACCT-1-1        1  15.469274        1  ...        41.632729
# AGAGAAACTAGAAG-1          1  12.026316        1  ...        36.266350
# AGAGAAACTAGAAG-1-1        1  12.026316        1  ...        36.266350
# ATTAGTGAGCTGTA-1          1  16.043103        1  ...        38.267441
# ATTAGTGAGCTGTA-1-1        1  16.043103        1  ...        38.267441
# CACAATCTTCAGAC-2          1  26.500000        1  ...        26.572042
# CACAATCTTCAGAC-2-1        1  26.500000        1  ...        26.572042
# CCACTTCTACTTTC-1          1  22.125000        1  ...        36.958061
# CCACTTCTACTTTC-1-1        1  22.125000        1  ...        36.958061
# CGAGGAGACATTTC-3          1  25.200000        1  ...        31.948593
# CGAGGAGACATTTC-3-1        1  25.200000        1  ...        31.948593
# CGAGGAGACTACGA-1          1  35.272727        1  ...        23.722282
# CGAGGAGACTACGA-1-1        1  35.272727        1  ...        23.722282
# CGTAGCCTTTTACC-1          1  19.720930        1  ...        32.190792
# CGTAGCCTTTTACC-1-1        1  19.720930        1  ...        32.190792
# GCAGTCCTCATGCA-1          1  13.113208        1  ...        41.337360
# GCAGTCCTCATGCA-1-1        1  13.113208        1  ...        41.337360
# GCGAGAGACTGTAG-1          1  13.951220        1  ...        36.792683
# GCGAGAGACTGTAG-1-1        1  13.951220        1  ...        36.792683
# GGACCCGAACCCTC-1          1  14.000000        1  ...        36.029247
# GGACCCGAACCCTC-1-1        1  14.000000        1  ...        36.029247
# GGCACGTGAGAAGT-1          1  18.277778        1  ...        30.620056
# GGCACGTGAGAAGT-1-1        1  18.277778        1  ...        30.620056
# GGGAAGTGGCTACA-2          1  29.210526        1  ...        24.759254
# GGGAAGTGGCTACA-2-1        1  29.210526        1  ...        24.759254
# GGGCAAGAGAGAGC-1          1  17.600000        1  ...        35.349014
# GGGCAAGAGAGAGC-1-1        1  17.600000        1  ...        35.349014
# GGGCCATGCGAGAG-1          1  15.688889        1  ...        36.542355
# GGGCCATGCGAGAG-1-1        1  15.688889        1  ...        36.542355
# GTAGCAACTCATTC-1          1  16.469880        1  ...        42.202713
# GTAGCAACTCATTC-1-1        1  16.469880        1  ...        42.202713
# TACCATTGTTTACC-1          1  19.000000        1  ...        34.942894
# TACCATTGTTTACC-1-1        1  19.000000        1  ...        34.942894
# TATAGCCTTCTCGC-1          1  36.657895        1  ...        22.256569
# TATAGCCTTCTCGC-1-1        1  36.657895        1  ...        22.256569
# TATCTGACACCACA-1          1  16.594595        1  ...        35.751228
# TATCTGACACCACA-1-1        1  16.594595        1  ...        35.751228
# TGCGAAACTGCGTA-1          1  16.966667        1  ...        27.923212
# TGCGAAACTGCGTA-1-1        1  16.966667        1  ...        27.923212
# TGGTAGACGCTAAC-1          1  15.792453        1  ...        39.372009
# TGGTAGACGCTAAC-1-1        1  15.792453        1  ...        39.372009
# TGTGAGACTGAAGA-2          1  30.454545        1  ...        26.794088
# TGTGAGACTGAAGA-2-1        1  30.454545        1  ...        26.794088
#
#                    potential_collision  read_count  source_verified  \
# cell_barcode
# AAAGAGACTGCCAA-1                  True       687.0            False
# AAAGAGACTGCCAA-1-1                True       687.0            False
# ACAAGCACTGACTG-1                  True      1046.0            False
# ACAAGCACTGACTG-1-1                True      1046.0            False
# AGAATACTCCACCT-1                  True      2769.0            False
# AGAATACTCCACCT-1-1                True      2769.0            False
# AGAGAAACTAGAAG-1                  True       457.0            False
# AGAGAAACTAGAAG-1-1                True       457.0            False
# ATTAGTGAGCTGTA-1                  True      1861.0            False
# ATTAGTGAGCTGTA-1-1                True      1861.0            False
# CACAATCTTCAGAC-2                  True       795.0            False
# CACAATCTTCAGAC-2-1                True       795.0            False
# CCACTTCTACTTTC-1                  True      1062.0            False
# CCACTTCTACTTTC-1-1                True      1062.0            False
# CGAGGAGACATTTC-3                  True       882.0            False
# CGAGGAGACATTTC-3-1                True       882.0            False
# CGAGGAGACTACGA-1                  True       388.0            False
# CGAGGAGACTACGA-1-1                True       388.0            False
# CGTAGCCTTTTACC-1                  True       848.0            False
# CGTAGCCTTTTACC-1-1                True       848.0            False
# GCAGTCCTCATGCA-1                  True       695.0            False
# GCAGTCCTCATGCA-1-1                True       695.0            False
# GCGAGAGACTGTAG-1                  True       572.0            False
# GCGAGAGACTGTAG-1-1                True       572.0            False
# GGACCCGAACCCTC-1                  True       672.0            False
# GGACCCGAACCCTC-1-1                True       672.0            False
# GGCACGTGAGAAGT-1                  True       329.0            False
# GGCACGTGAGAAGT-1-1                True       329.0            False
# GGGAAGTGGCTACA-2                  True       555.0            False
# GGGAAGTGGCTACA-2-1                True       555.0            False
# GGGCAAGAGAGAGC-1                  True       616.0            False
# GGGCAAGAGAGAGC-1-1                True       616.0            False
# GGGCCATGCGAGAG-1                  True       706.0            False
# GGGCCATGCGAGAG-1-1                True       706.0            False
# GTAGCAACTCATTC-1                  True      1367.0            False
# GTAGCAACTCATTC-1-1                True      1367.0            False
# TACCATTGTTTACC-1                  True       741.0            False
# TACCATTGTTTACC-1-1                True       741.0            False
# TATAGCCTTCTCGC-1                  True      1393.0            False
# TATAGCCTTCTCGC-1-1                True      1393.0            False
# TATCTGACACCACA-1                  True      1228.0            False
# TATCTGACACCACA-1-1                True      1228.0            False
# TGCGAAACTGCGTA-1                  True       509.0            False
# TGCGAAACTGCGTA-1-1                True       509.0            False
# TGGTAGACGCTAAC-1                  True       837.0            False
# TGGTAGACGCTAAC-1-1                True       837.0            False
# TGTGAGACTGAAGA-2                  True       335.0            False
# TGTGAGACTGAAGA-2-1                True       335.0            False
#
#                     total_counts  total_counts_hb  total_counts_mt  \
# cell_barcode
# AAAGAGACTGCCAA-1         10777.0             38.0              0.0
# AAAGAGACTGCCAA-1-1       10777.0             38.0              0.0
# ACAAGCACTGACTG-1         12281.0            225.0              0.0
# ACAAGCACTGACTG-1-1       12281.0            225.0              0.0
# AGAATACTCCACCT-1         10559.0             47.0              0.0
# AGAATACTCCACCT-1-1       10559.0             47.0              0.0
# AGAGAAACTAGAAG-1          7569.0             79.0              0.0
# AGAGAAACTAGAAG-1-1        7569.0             79.0              0.0
# ATTAGTGAGCTGTA-1         10978.0             51.0              0.0
# ATTAGTGAGCTGTA-1-1       10978.0             51.0              0.0
# CACAATCTTCAGAC-2         11625.0             46.0            386.0
# CACAATCTTCAGAC-2-1       11625.0             46.0            386.0
# CCACTTCTACTTTC-1          9895.0            123.0              0.0
# CCACTTCTACTTTC-1-1        9895.0            123.0              0.0
# CGAGGAGACATTTC-3         11049.0             21.0            332.0
# CGAGGAGACATTTC-3-1       11049.0             21.0            332.0
# CGAGGAGACTACGA-1         14792.0            237.0            594.0
# CGAGGAGACTACGA-1-1       14792.0            237.0            594.0
# CGTAGCCTTTTACC-1         14529.0            226.0              0.0
# CGTAGCCTTTTACC-1-1       14529.0            226.0              0.0
# GCAGTCCTCATGCA-1         11261.0             52.0              0.0
# GCAGTCCTCATGCA-1-1       11261.0             52.0              0.0
# GCGAGAGACTGTAG-1          8200.0            111.0              0.0
# GCGAGAGACTGTAG-1-1        8200.0            111.0              0.0
# GGACCCGAACCCTC-1         13403.0            100.0              0.0
# GGACCCGAACCCTC-1-1       13403.0            100.0              0.0
# GGCACGTGAGAAGT-1          3919.0             83.0              0.0
# GGCACGTGAGAAGT-1-1        3919.0             83.0              0.0
# GGGAAGTGGCTACA-2         13292.0            180.0            653.0
# GGGAAGTGGCTACA-2-1       13292.0            180.0            653.0
# GGGCAAGAGAGAGC-1          7822.0             55.0              0.0
# GGGCAAGAGAGAGC-1-1        7822.0             55.0              0.0
# GGGCCATGCGAGAG-1         10377.0            226.0              0.0
# GGGCCATGCGAGAG-1-1       10377.0            226.0              0.0
# GTAGCAACTCATTC-1         11504.0             92.0              0.0
# GTAGCAACTCATTC-1-1       11504.0             92.0              0.0
# TACCATTGTTTACC-1         10769.0            144.0              0.0
# TACCATTGTTTACC-1-1       10769.0            144.0              0.0
# TATAGCCTTCTCGC-1         14234.0             44.0            316.0
# TATAGCCTTCTCGC-1-1       14234.0             44.0            316.0
# TATCTGACACCACA-1          7541.0             58.0              0.0
# TATCTGACACCACA-1-1        7541.0             58.0              0.0
# TGCGAAACTGCGTA-1          6876.0              8.0              0.0
# TGCGAAACTGCGTA-1-1        6876.0              8.0              0.0
# TGGTAGACGCTAAC-1          8567.0             53.0              0.0
# TGGTAGACGCTAAC-1-1        8567.0             53.0              0.0
# TGTGAGACTGAAGA-2         14074.0             92.0            592.0
# TGTGAGACTGAAGA-2-1       14074.0             92.0            592.0
#
#                     total_counts_ribo     condition_adamson       experiment
# cell_barcode
# AAAGAGACTGCCAA-1               4095.0        SPI1|IRE1_only  pilot|epistasis
# AAAGAGACTGCCAA-1-1             4095.0        SPI1|IRE1_only  pilot|epistasis
# ACAAGCACTGACTG-1               4756.0     EP300|3x_neg_ctrl  pilot|epistasis
# ACAAGCACTGACTG-1-1             4756.0     EP300|3x_neg_ctrl  pilot|epistasis
# AGAATACTCCACCT-1               4396.0       EP300|ATF6_IRE1  pilot|epistasis
# AGAATACTCCACCT-1-1             4396.0       EP300|ATF6_IRE1  pilot|epistasis
# AGAGAAACTAGAAG-1               2745.0        SPI1|ATF6_PERK  pilot|epistasis
# AGAGAAACTAGAAG-1-1             2745.0        SPI1|ATF6_PERK  pilot|epistasis
# ATTAGTGAGCTGTA-1               4201.0     EP300|3x_neg_ctrl  pilot|epistasis
# ATTAGTGAGCTGTA-1-1             4201.0     EP300|3x_neg_ctrl  pilot|epistasis
# CACAATCTTCAGAC-2               3089.0     DNAJC19|PERK_IRE1    upr|epistasis
# CACAATCTTCAGAC-2-1             3089.0     DNAJC19|PERK_IRE1    upr|epistasis
# CCACTTCTACTTTC-1               3657.0       SNAI1|ATF6_PERK  pilot|epistasis
# CCACTTCTACTTTC-1-1             3657.0       SNAI1|ATF6_PERK  pilot|epistasis
# CGAGGAGACATTTC-3               3530.0     DNAJC19|ATF6_only    upr|epistasis
# CGAGGAGACATTTC-3-1             3530.0     DNAJC19|ATF6_only    upr|epistasis
# CGAGGAGACTACGA-1               3509.0      SEC61B|ATF6_PERK    upr|epistasis
# CGAGGAGACTACGA-1-1             3509.0      SEC61B|ATF6_PERK    upr|epistasis
# CGTAGCCTTTTACC-1               4677.0        SPI1|ATF6_IRE1  pilot|epistasis
# CGTAGCCTTTTACC-1-1             4677.0        SPI1|ATF6_IRE1  pilot|epistasis
# GCAGTCCTCATGCA-1               4655.0           EP300|ASCC3        pilot|upr
# GCAGTCCTCATGCA-1-1             4655.0           EP300|ASCC3        pilot|upr
# GCGAGAGACTGTAG-1               3017.0       EP300|PERK_IRE1  pilot|epistasis
# GCGAGAGACTGTAG-1-1             3017.0       EP300|PERK_IRE1  pilot|epistasis
# GGACCCGAACCCTC-1               4829.0        SPI1|ATF6_IRE1  pilot|epistasis
# GGACCCGAACCCTC-1-1             4829.0        SPI1|ATF6_IRE1  pilot|epistasis
# GGCACGTGAGAAGT-1               1200.0       SNAI1|ATF6_only  pilot|epistasis
# GGCACGTGAGAAGT-1-1             1200.0       SNAI1|ATF6_only  pilot|epistasis
# GGGAAGTGGCTACA-2               3291.0      SEC61B|ATF6_only    upr|epistasis
# GGGAAGTGGCTACA-2-1             3291.0      SEC61B|ATF6_only    upr|epistasis
# GGGCAAGAGAGAGC-1               2765.0       EP300|IRE1_only  pilot|epistasis
# GGGCAAGAGAGAGC-1-1             2765.0       EP300|IRE1_only  pilot|epistasis
# GGGCCATGCGAGAG-1               3792.0  SNAI1|ATF6_PERK_IRE1  pilot|epistasis
# GGGCCATGCGAGAG-1-1             3792.0  SNAI1|ATF6_PERK_IRE1  pilot|epistasis
# GTAGCAACTCATTC-1               4855.0  EP300|ATF6_PERK_IRE1  pilot|epistasis
# GTAGCAACTCATTC-1-1             4855.0  EP300|ATF6_PERK_IRE1  pilot|epistasis
# TACCATTGTTTACC-1               3763.0     SNAI1|3x_neg_ctrl  pilot|epistasis
# TACCATTGTTTACC-1-1             3763.0     SNAI1|3x_neg_ctrl  pilot|epistasis
# TATAGCCTTCTCGC-1               3168.0     DNAJC19|ATF6_IRE1    upr|epistasis
# TATAGCCTTCTCGC-1-1             3168.0     DNAJC19|ATF6_IRE1    upr|epistasis
# TATCTGACACCACA-1               2696.0       EP300|ATF6_only  pilot|epistasis
# TATCTGACACCACA-1-1             2696.0       EP300|ATF6_only  pilot|epistasis
# TGCGAAACTGCGTA-1               1920.0       SNAI1|ATF6_only  pilot|epistasis
# TGCGAAACTGCGTA-1-1             1920.0       SNAI1|ATF6_only  pilot|epistasis
# TGGTAGACGCTAAC-1               3373.0   SPI1|ATF6_PERK_IRE1  pilot|epistasis
# TGGTAGACGCTAAC-1-1             3373.0   SPI1|ATF6_PERK_IRE1  pilot|epistasis
# TGTGAGACTGAAGA-2               3771.0  ASCC3|ATF6_PERK_IRE1    upr|epistasis
# TGTGAGACTGAAGA-2-1             3771.0  ASCC3|ATF6_PERK_IRE1    upr|epistasis
#
# [48 rows x 37 columns]

# %% [markdown]
# ### remove these cells from the main barcode_collisions dataframe and replace them with the data just created

# %%
barcodes_to_drop = combined_obs_barcode_collisions[
     combined_obs_barcode_collisions['original_barcode'].isin(agreement_counts.index[agreement_counts['count_agree'] == 0])
].index
barcodes_to_drop
# Out:
# Index(['AAAGAGACTGCCAA-1', 'AAAGAGACTGCCAA-1', 'ACAAGCACTGACTG-1',
#        'ACAAGCACTGACTG-1', 'AGAATACTCCACCT-1', 'AGAATACTCCACCT-1',
#        'AGAGAAACTAGAAG-1', 'AGAGAAACTAGAAG-1', 'ATTAGTGAGCTGTA-1',
#        'ATTAGTGAGCTGTA-1', 'CCACTTCTACTTTC-1', 'CCACTTCTACTTTC-1',
#        'CGTAGCCTTTTACC-1', 'CGTAGCCTTTTACC-1', 'GCAGTCCTCATGCA-1',
#        'GCAGTCCTCATGCA-1', 'GCGAGAGACTGTAG-1', 'GCGAGAGACTGTAG-1',
#        'GGACCCGAACCCTC-1', 'GGACCCGAACCCTC-1', 'GGCACGTGAGAAGT-1',
#        'GGCACGTGAGAAGT-1', 'GGGCAAGAGAGAGC-1', 'GGGCAAGAGAGAGC-1',
#        'GGGCCATGCGAGAG-1', 'GGGCCATGCGAGAG-1', 'GTAGCAACTCATTC-1',
#        'GTAGCAACTCATTC-1', 'TACCATTGTTTACC-1', 'TACCATTGTTTACC-1',
#        'TATCTGACACCACA-1', 'TATCTGACACCACA-1', 'TGCGAAACTGCGTA-1',
#        'TGCGAAACTGCGTA-1', 'TGGTAGACGCTAAC-1', 'TGGTAGACGCTAAC-1',
#        'AAAGAGACTGCCAA-1-1', 'AAAGAGACTGCCAA-1-1', 'ACAAGCACTGACTG-1-1',
#        'ACAAGCACTGACTG-1-1', 'AGAATACTCCACCT-1-1', 'AGAATACTCCACCT-1-1',
#        'AGAGAAACTAGAAG-1-1', 'AGAGAAACTAGAAG-1-1', 'ATTAGTGAGCTGTA-1-1',
#        'ATTAGTGAGCTGTA-1-1', 'CCACTTCTACTTTC-1-1', 'CCACTTCTACTTTC-1-1',
#        'CGAGGAGACTACGA-1', 'CGAGGAGACTACGA-1', 'CGTAGCCTTTTACC-1-1',
#        'CGTAGCCTTTTACC-1-1', 'GCGAGAGACTGTAG-1-1', 'GCGAGAGACTGTAG-1-1',
#        'GGACCCGAACCCTC-1-1', 'GGACCCGAACCCTC-1-1', 'GGCACGTGAGAAGT-1-1',
#        'GGCACGTGAGAAGT-1-1', 'GGGCAAGAGAGAGC-1-1', 'GGGCAAGAGAGAGC-1-1',
#        'GGGCCATGCGAGAG-1-1', 'GGGCCATGCGAGAG-1-1', 'GTAGCAACTCATTC-1-1',
#        'GTAGCAACTCATTC-1-1', 'TACCATTGTTTACC-1-1', 'TACCATTGTTTACC-1-1',
#        'TATAGCCTTCTCGC-1', 'TATAGCCTTCTCGC-1', 'TATCTGACACCACA-1-1',
#        'TATCTGACACCACA-1-1', 'TGCGAAACTGCGTA-1-1', 'TGCGAAACTGCGTA-1-1',
#        'TGGTAGACGCTAAC-1-1', 'TGGTAGACGCTAAC-1-1', 'CACAATCTTCAGAC-2',
#        'CACAATCTTCAGAC-2', 'GGGAAGTGGCTACA-2', 'GGGAAGTGGCTACA-2',
#        'TGTGAGACTGAAGA-2', 'TGTGAGACTGAAGA-2', 'CGAGGAGACATTTC-3',
#        'CGAGGAGACATTTC-3', 'CGAGGAGACTACGA-1-1', 'CGAGGAGACTACGA-1-1',
#        'GCAGTCCTCATGCA-1-1', 'GCAGTCCTCATGCA-1-1', 'TATAGCCTTCTCGC-1-1',
#        'TATAGCCTTCTCGC-1-1', 'CACAATCTTCAGAC-2-1', 'CACAATCTTCAGAC-2-1',
#        'GGGAAGTGGCTACA-2-1', 'GGGAAGTGGCTACA-2-1', 'TGTGAGACTGAAGA-2-1',
#        'TGTGAGACTGAAGA-2-1', 'CGAGGAGACATTTC-3-1', 'CGAGGAGACATTTC-3-1'],
#       dtype='object', name='cell_barcode')

# %%
combined_obs_barcode_collisions.drop(barcodes_to_drop, inplace=True)
combined_obs_barcode_collisions
# Out:
#                    condition_gears cell_type dose_val  control  \
# cell_barcode
# AAATCCCTCTTGGA-1              ctrl   K562(?)        1        1
# AAATCCCTCTTGGA-1              ctrl   K562(?)        1        1
# AAGCCATGATTCGG-1      BHLHE40+ctrl   K562(?)      1+1        0
# AAGCCATGATTCGG-1      BHLHE40+ctrl   K562(?)      1+1        0
# AATCAAACTCCCGT-1       ZNF326+ctrl   K562(?)      1+1        0
# ...                            ...       ...      ...      ...
# TGTAACCTCACCAA-3-1      SRPRB+ctrl   K562(?)      1+1        0
# TGTATCTGAACGTC-3-1     TMED10+ctrl   K562(?)      1+1        0
# TGTATCTGAACGTC-3-1     TMED10+ctrl   K562(?)      1+1        0
# TTCAGTTGCGGGAA-3-1       CARS+ctrl   K562(?)      1+1        0
# TTCAGTTGCGGGAA-3-1       CARS+ctrl   K562(?)      1+1        0
#
#                               condition_name  potential_collision  \
# cell_barcode
# AAATCCCTCTTGGA-1              K562(?)_ctrl_1                 True
# AAATCCCTCTTGGA-1              K562(?)_ctrl_1                 True
# AAGCCATGATTCGG-1    K562(?)_BHLHE40+ctrl_1+1                 True
# AAGCCATGATTCGG-1    K562(?)_BHLHE40+ctrl_1+1                 True
# AATCAAACTCCCGT-1     K562(?)_ZNF326+ctrl_1+1                 True
# ...                                      ...                  ...
# TGTAACCTCACCAA-3-1    K562(?)_SRPRB+ctrl_1+1                 True
# TGTATCTGAACGTC-3-1   K562(?)_TMED10+ctrl_1+1                 True
# TGTATCTGAACGTC-3-1   K562(?)_TMED10+ctrl_1+1                 True
# TTCAGTTGCGGGAA-3-1     K562(?)_CARS+ctrl_1+1                 True
# TTCAGTTGCGGGAA-3-1     K562(?)_CARS+ctrl_1+1                 True
#
#                     original_barcode  barcode_collision        guide_identity  \
# cell_barcode
# AAATCCCTCTTGGA-1    AAATCCCTCTTGGA-1               True        62(mod)_pBA581
# AAATCCCTCTTGGA-1    AAATCCCTCTTGGA-1               True           DAD1_pDS499
# AAGCCATGATTCGG-1    AAGCCATGATTCGG-1               True        BHLHE40_pDS258
# AAGCCATGATTCGG-1    AAGCCATGATTCGG-1               True        SEC61A1_pDS031
# AATCAAACTCCCGT-1    AATCAAACTCCCGT-1               True         ZNF326_pDS262
# ...                              ...                ...                   ...
# TGTAACCTCACCAA-3-1  TGTAACCTCACCAA-3               True  3x_neg_ctrl_pMJ144-2
# TGTATCTGAACGTC-3-1  TGTATCTGAACGTC-3               True         TMED10_pDS036
# TGTATCTGAACGTC-3-1  TGTATCTGAACGTC-3               True      PERK_only_pMJ146
# TTCAGTTGCGGGAA-3-1  TTCAGTTGCGGGAA-3               True           CARS_pDS460
# TTCAGTTGCGGGAA-3-1  TTCAGTTGCGGGAA-3               True      PERK_only_pMJ146
#
#                     read_count  ...  log1p_total_counts_ribo  pct_counts_ribo  \
# cell_barcode                    ...
# AAATCCCTCTTGGA-1         524.0  ...                 8.024862        35.975037
# AAATCCCTCTTGGA-1         585.0  ...                 7.509883        24.313883
# AAGCCATGATTCGG-1         837.0  ...                 7.910957        34.345470
# AAGCCATGATTCGG-1        3254.0  ...                 8.787830        31.981453
# AATCAAACTCCCGT-1        1325.0  ...                 8.076204        37.942425
# ...                        ...  ...                      ...              ...
# TGTAACCTCACCAA-3-1       240.0  ...                 8.842605        28.970829
# TGTATCTGAACGTC-3-1      1266.0  ...                 8.415382        20.475262
# TGTATCTGAACGTC-3-1       176.0  ...                 8.449343        25.297876
# TTCAGTTGCGGGAA-3-1       684.0  ...                 7.693481        24.917624
# TTCAGTTGCGGGAA-3-1       330.0  ...                 9.219399        34.170956
#
#                     total_counts_hb  log1p_total_counts_hb pct_counts_hb  \
# cell_barcode
# AAATCCCTCTTGGA-1               83.0               4.430817      0.977390
# AAATCCCTCTTGGA-1              145.0               4.983607      1.931788
# AAGCCATGATTCGG-1              128.0               4.859812      1.612700
# AAGCCATGATTCGG-1              355.0               5.874931      1.732552
# AATCAAACTCCCGT-1               69.0               4.248495      0.814063
# ...                             ...                    ...           ...
# TGTAACCTCACCAA-3-1            314.0               5.752573      1.314192
# TGTATCTGAACGTC-3-1            375.0               5.929589      1.700603
# TGTATCTGAACGTC-3-1            404.0               6.003887      2.188042
# TTCAGTTGCGGGAA-3-1            112.0               4.727388      1.272583
# TTCAGTTGCGGGAA-3-1            394.0               5.978886      1.334327
#
#                     experiment  condition_gears_harmonized  condition_agrees  \
# cell_barcode
# AAATCCCTCTTGGA-1         pilot                     control              True
# AAATCCCTCTTGGA-1           upr                     control             False
# AAGCCATGATTCGG-1         pilot                     BHLHE40              True
# AAGCCATGATTCGG-1           upr                     BHLHE40             False
# AATCAAACTCCCGT-1         pilot                      ZNF326              True
# ...                        ...                         ...               ...
# TGTAACCTCACCAA-3-1   epistasis                       SRPRB             False
# TGTATCTGAACGTC-3-1         upr                      TMED10              True
# TGTATCTGAACGTC-3-1   epistasis                      TMED10             False
# TTCAGTTGCGGGAA-3-1         upr                        CARS              True
# TTCAGTTGCGGGAA-3-1   epistasis                        CARS             False
#
#                      keep  source_verified
# cell_barcode
# AAATCCCTCTTGGA-1     True             True
# AAATCCCTCTTGGA-1    False            False
# AAGCCATGATTCGG-1     True             True
# AAGCCATGATTCGG-1    False            False
# AATCAAACTCCCGT-1     True             True
# ...                   ...              ...
# TGTAACCTCACCAA-3-1  False            False
# TGTATCTGAACGTC-3-1   True             True
# TGTATCTGAACGTC-3-1  False            False
# TTCAGTTGCGGGAA-3-1   True             True
# TTCAGTTGCGGGAA-3-1  False            False
#
# [592 rows x 37 columns]

# %%
combined_obs_barcode_collisions_resolved = pd.concat([combined_obs_barcode_collisions[combined_obs_barcode_collisions['keep']], agreement_0_replacement_rows])

# make sure indices are unique or else duplicated cells were added
assert(combined_obs_barcode_collisions_resolved.index.is_unique)
print(f"Index is unique? {combined_obs_barcode_collisions_resolved.index.is_unique}")

combined_obs_barcode_collisions_resolved
# Out:
# Index is unique? True
#                    condition_gears cell_type dose_val  control  \
# cell_barcode
# AAATCCCTCTTGGA-1              ctrl   K562(?)        1        1
# AAGCCATGATTCGG-1      BHLHE40+ctrl   K562(?)      1+1        0
# AATCAAACTCCCGT-1       ZNF326+ctrl   K562(?)      1+1        0
# AATGTAACTTCTGT-1      BHLHE40+ctrl   K562(?)      1+1        0
# ACAAGAGAACGTGT-1              ctrl   K562(?)        1        1
# ...                            ...       ...      ...      ...
# TGCGAAACTGCGTA-1-1            ctrl   K562(?)        1        1
# TGGTAGACGCTAAC-1              ctrl   K562(?)        1        1
# TGGTAGACGCTAAC-1-1            ctrl   K562(?)        1        1
# TGTGAGACTGAAGA-2              ctrl   K562(?)        1        1
# TGTGAGACTGAAGA-2-1            ctrl   K562(?)        1        1
#
#                               condition_name  potential_collision  \
# cell_barcode
# AAATCCCTCTTGGA-1              K562(?)_ctrl_1                 True
# AAGCCATGATTCGG-1    K562(?)_BHLHE40+ctrl_1+1                 True
# AATCAAACTCCCGT-1     K562(?)_ZNF326+ctrl_1+1                 True
# AATGTAACTTCTGT-1    K562(?)_BHLHE40+ctrl_1+1                 True
# ACAAGAGAACGTGT-1              K562(?)_ctrl_1                 True
# ...                                      ...                  ...
# TGCGAAACTGCGTA-1-1            K562(?)_ctrl_1                 True
# TGGTAGACGCTAAC-1              K562(?)_ctrl_1                 True
# TGGTAGACGCTAAC-1-1            K562(?)_ctrl_1                 True
# TGTGAGACTGAAGA-2              K562(?)_ctrl_1                 True
# TGTGAGACTGAAGA-2-1            K562(?)_ctrl_1                 True
#
#                     original_barcode  barcode_collision  guide_identity  \
# cell_barcode
# AAATCCCTCTTGGA-1    AAATCCCTCTTGGA-1               True  62(mod)_pBA581
# AAGCCATGATTCGG-1    AAGCCATGATTCGG-1               True  BHLHE40_pDS258
# AATCAAACTCCCGT-1    AATCAAACTCCCGT-1               True   ZNF326_pDS262
# AATGTAACTTCTGT-1    AATGTAACTTCTGT-1               True  BHLHE40_pDS258
# ACAAGAGAACGTGT-1    ACAAGAGAACGTGT-1               True    EP300_pDS268
# ...                              ...                ...             ...
# TGCGAAACTGCGTA-1-1  TGCGAAACTGCGTA-1               True    SNAI1_pDS266
# TGGTAGACGCTAAC-1    TGGTAGACGCTAAC-1               True     SPI1_pDS255
# TGGTAGACGCTAAC-1-1  TGGTAGACGCTAAC-1               True     SPI1_pDS255
# TGTGAGACTGAAGA-2    TGTGAGACTGAAGA-2               True    ASCC3_pDS052
# TGTGAGACTGAAGA-2-1  TGTGAGACTGAAGA-2               True    ASCC3_pDS052
#
#                     read_count  ...  log1p_total_counts_ribo  pct_counts_ribo  \
# cell_barcode                    ...
# AAATCCCTCTTGGA-1         524.0  ...                 8.024862        35.975037
# AAGCCATGATTCGG-1         837.0  ...                 7.910957        34.345470
# AATCAAACTCCCGT-1        1325.0  ...                 8.076204        37.942425
# AATGTAACTTCTGT-1         878.0  ...                 8.581669        38.812054
# ACAAGAGAACGTGT-1         155.0  ...                 8.303752        36.944191
# ...                        ...  ...                      ...              ...
# TGCGAAACTGCGTA-1-1       509.0  ...                 7.560601        27.923212
# TGGTAGACGCTAAC-1         837.0  ...                 8.123855        39.372009
# TGGTAGACGCTAAC-1-1       837.0  ...                 8.123855        39.372009
# TGTGAGACTGAAGA-2         335.0  ...                 8.235361        26.794088
# TGTGAGACTGAAGA-2-1       335.0  ...                 8.235361        26.794088
#
#                     total_counts_hb  log1p_total_counts_hb pct_counts_hb  \
# cell_barcode
# AAATCCCTCTTGGA-1               83.0               4.430817      0.977390
# AAGCCATGATTCGG-1              128.0               4.859812      1.612700
# AATCAAACTCCCGT-1               69.0               4.248495      0.814063
# AATGTAACTTCTGT-1              139.0               4.941642      1.011792
# ACAAGAGAACGTGT-1               95.0               4.564348      0.869167
# ...                             ...                    ...           ...
# TGCGAAACTGCGTA-1-1              8.0               2.197225      0.116347
# TGGTAGACGCTAAC-1               53.0               3.988984      0.618653
# TGGTAGACGCTAAC-1-1             53.0               3.988984      0.618653
# TGTGAGACTGAAGA-2               92.0               4.532599      0.653688
# TGTGAGACTGAAGA-2-1             92.0               4.532599      0.653688
#
#                          experiment  condition_gears_harmonized  \
# cell_barcode
# AAATCCCTCTTGGA-1              pilot                     control
# AAGCCATGATTCGG-1              pilot                     BHLHE40
# AATCAAACTCCCGT-1              pilot                      ZNF326
# AATGTAACTTCTGT-1              pilot                     BHLHE40
# ACAAGAGAACGTGT-1              pilot                     control
# ...                             ...                         ...
# TGCGAAACTGCGTA-1-1  pilot|epistasis                     control
# TGGTAGACGCTAAC-1    pilot|epistasis                     control
# TGGTAGACGCTAAC-1-1  pilot|epistasis                     control
# TGTGAGACTGAAGA-2      upr|epistasis                     control
# TGTGAGACTGAAGA-2-1    upr|epistasis                     control
#
#                     condition_agrees  keep  source_verified
# cell_barcode
# AAATCCCTCTTGGA-1                True  True             True
# AAGCCATGATTCGG-1                True  True             True
# AATCAAACTCCCGT-1                True  True             True
# AATGTAACTTCTGT-1                True  True             True
# ACAAGAGAACGTGT-1               False  True             True
# ...                              ...   ...              ...
# TGCGAAACTGCGTA-1-1             False  True            False
# TGGTAGACGCTAAC-1               False  True            False
# TGGTAGACGCTAAC-1-1             False  True            False
# TGTGAGACTGAAGA-2               False  True            False
# TGTGAGACTGAAGA-2-1             False  True            False
#
# [344 rows x 37 columns]

# %%
combined_obs_barcode_collisions_resolved['condition_corrected'] = where(combined_obs_barcode_collisions_resolved['source_verified'],
                                                                        combined_obs_barcode_collisions_resolved['condition_adamson'],
                                                                        'ambiguous')
combined_obs_barcode_collisions_resolved['condition_corrected'].value_counts()
# Out:
# condition_corrected
# ambiguous      48
# control        44
# 3x_neg_ctrl    24
# ATF6_only      16
# ATF6_PERK      14
#                ..
# DHDDS           1
# GBF1            1
# GMPPB           1
# SPCS2           1
# DNAJC19         1
# Name: count, Length: 82, dtype: int64

# %%
combined_obs_barcode_collisions_resolved.value_counts('source_verified')
# Out:
# source_verified
# True     296
# False     48
# Name: count, dtype: int64

# %%
combined_obs_barcode_collisions_resolved.value_counts(['source_verified', 'condition_agrees'])
# Out:
# source_verified  condition_agrees
# True             True                188
#                  False               108
# False            False                48
# Name: count, dtype: int64

# %%
combined_obs_barcode_collisions_resolved[~combined_obs_barcode_collisions_resolved['condition_agrees']][columns_of_interest]
# Out:
#                     original_barcode condition_gears  \
# cell_barcode
# ACAAGAGAACGTGT-1    ACAAGAGAACGTGT-1            ctrl
# AGAAAGTGGGTTTG-1    AGAAAGTGGGTTTG-1            ctrl
# CTGGCACTGTTCTT-1    CTGGCACTGTTCTT-1            ctrl
# GCACGGTGGTTTCT-1    GCACGGTGGTTTCT-1            ctrl
# GCGAAGGAGGAAAT-1    GCGAAGGAGGAAAT-1            ctrl
# ...                              ...             ...
# TGCGAAACTGCGTA-1-1  TGCGAAACTGCGTA-1            ctrl
# TGGTAGACGCTAAC-1    TGGTAGACGCTAAC-1            ctrl
# TGGTAGACGCTAAC-1-1  TGGTAGACGCTAAC-1            ctrl
# TGTGAGACTGAAGA-2    TGTGAGACTGAAGA-2            ctrl
# TGTGAGACTGAAGA-2-1  TGTGAGACTGAAGA-2            ctrl
#
#                    condition_gears_harmonized     condition_adamson  \
# cell_barcode
# ACAAGAGAACGTGT-1                      control                 EP300
# AGAAAGTGGGTTTG-1                      control                  SPI1
# CTGGCACTGTTCTT-1                      control                 EP300
# GCACGGTGGTTTCT-1                      control                 SNAI1
# GCGAAGGAGGAAAT-1                      control                 EP300
# ...                                       ...                   ...
# TGCGAAACTGCGTA-1-1                    control       SNAI1|ATF6_only
# TGGTAGACGCTAAC-1                      control   SPI1|ATF6_PERK_IRE1
# TGGTAGACGCTAAC-1-1                    control   SPI1|ATF6_PERK_IRE1
# TGTGAGACTGAAGA-2                      control  ASCC3|ATF6_PERK_IRE1
# TGTGAGACTGAAGA-2-1                    control  ASCC3|ATF6_PERK_IRE1
#
#                     condition_agrees       experiment
# cell_barcode
# ACAAGAGAACGTGT-1               False            pilot
# AGAAAGTGGGTTTG-1               False            pilot
# CTGGCACTGTTCTT-1               False            pilot
# GCACGGTGGTTTCT-1               False            pilot
# GCGAAGGAGGAAAT-1               False            pilot
# ...                              ...              ...
# TGCGAAACTGCGTA-1-1             False  pilot|epistasis
# TGGTAGACGCTAAC-1               False  pilot|epistasis
# TGGTAGACGCTAAC-1-1             False  pilot|epistasis
# TGTGAGACTGAAGA-2               False    upr|epistasis
# TGTGAGACTGAAGA-2-1             False    upr|epistasis
#
# [156 rows x 6 columns]

# %% [markdown]
# # Deal with potential collisions

# %%
combined_obs_potential_collisions[columns_of_interest]
# Out:
#                   original_barcode condition_gears condition_gears_harmonized  \
# cell_barcode
# ACTCTCCTCACACA-1  ACTCTCCTCACACA-1            ctrl                    control
# ACTCTCCTCACACA-1  ACTCTCCTCACACA-1            ctrl                    control
# ATCCAGGAGCTCCT-1  ATCCAGGAGCTCCT-1            ctrl                    control
# ATCCAGGAGCTCCT-1  ATCCAGGAGCTCCT-1            ctrl                    control
# ATTGAAACCGACTA-1  ATTGAAACCGACTA-1    BHLHE40+ctrl                    BHLHE40
# ...                            ...             ...                        ...
# CAGCTCACATGTGC-3  CAGCTCACATGTGC-3       TTI1+ctrl                       TTI1
# GAGTCTGAAAAGTG-3  GAGTCTGAAAAGTG-3      SLMO2+ctrl                      SLMO2
# GAGTCTGAAAAGTG-3  GAGTCTGAAAAGTG-3      SLMO2+ctrl                      SLMO2
# TGAATAACCGCCTT-3  TGAATAACCGCCTT-3      STT3A+ctrl                      STT3A
# TGAATAACCGCCTT-3  TGAATAACCGCCTT-3      STT3A+ctrl                      STT3A
#
#                  condition_adamson  condition_agrees experiment
# cell_barcode
# ACTCTCCTCACACA-1             SNAI1             False      pilot
# ACTCTCCTCACACA-1             STT3A             False        upr
# ATCCAGGAGCTCCT-1             EP300             False      pilot
# ATCCAGGAGCTCCT-1       Gal4-4(mod)             False        upr
# ATTGAAACCGACTA-1           BHLHE40              True      pilot
# ...                            ...               ...        ...
# CAGCTCACATGTGC-3    ATF6_PERK_IRE1             False  epistasis
# GAGTCTGAAAAGTG-3             SLMO2              True        upr
# GAGTCTGAAAAGTG-3               NaN             False  epistasis
# TGAATAACCGCCTT-3             STT3A              True        upr
# TGAATAACCGCCTT-3         PERK_only             False  epistasis
#
# [120 rows x 6 columns]

# %%
combined_obs_potential_collisions.value_counts('condition_agrees')
# Out:
# condition_agrees
# False    94
# True     26
# Name: count, dtype: int64

# %% [markdown]
# ### check for agreement within a barcode pair to see if all 26 agreements are paired with a disagreement, otherwise cannot disambiguate which Adamson 2016 cell was the true source in GEARS

# %%
(combined_obs_potential_collisions
     .groupby('original_barcode')
     .agg(count_agree=pd.NamedAgg('condition_agrees', 'sum'))
     .value_counts('count_agree')
)
# Out:
# count_agree
# 0    34
# 1    26
# Name: count, dtype: int64

# %% [markdown]
# ### pull out the 26 unique matching ones and mark them as `keep` and `source_verified`

# %%
(combined_obs_potential_collisions
     .groupby('original_barcode')
     .agg(count_agree=pd.NamedAgg('condition_agrees', 'sum'))
     .sort_values('count_agree', ascending=False)
)
# Out:
#                   count_agree
# original_barcode
# AAAGGCCTTCTGGA-1            1
# CACTTTGACCAAGT-1            1
# CAGCTCACATGTGC-3            1
# CATCGCTGGTACCA-1            1
# CCAAGTGACTGAGT-1            1
# CCAATTTGCTCGAA-2            1
# CGACTCTGTCTCCG-1            1
# CGTCCAACAGACTC-2            1
# GAGTCTGAAAAGTG-3            1
# GCACCACTGATAGA-1            1
# GCACTAGAGGAAGC-1            1
# GCCGAGTGCAACCA-1            1
# GCTCAGCTGTCTGA-2            1
# GGACATTGTGCTGA-1            1
# TAAAGACTACGTAC-1            1
# TAAGTAACTGTCTT-1            1
# TAATCCACTCAGTG-1            1
# TGAATAACCGCCTT-3            1
# TGTAAAACTCGCCT-1            1
# CAGACAACGGTCAT-1            1
# CGGTCACTGGTTCA-2            1
# AGTGTTCTATGGTC-3            1
# ATTGCTTGCTTCTA-1            1
# AACACTCTCATACG-2            1
# ATTGAAACCGACTA-1            1
# AGCTTTACTTCGCC-1            1
# GTGAACACTCCTGC-1            0
# ACTGCCACTAGAGA-1            0
# ACTCTCCTCACACA-1            0
# ACCCGTTGTGGTCA-1            0
# TACATCACTGACCA-3            0
# TACTACTGCGTCTC-1            0
# TAGTTGCTACCCTC-3            0
# TATCAGCTGAGGGT-3            0
# TCACCTCTCTCTAT-1            0
# TCAGGATGCTTCTA-3            0
# TCGCAGCTAACGGG-1            0
# AACTCACTCTCATT-1            0
# TGGGTATGTGGAAA-1            0
# TGTATCTGACCCAA-3            0
# GGTGATACTTCTCA-1            0
# CACTTATGCTTATC-2            0
# AGGGTTTGCTCCAC-1            0
# CACGCTACGACAGG-3            0
# CATAAAACTCGTAG-2            0
# CACGATGAGTAAAG-3            0
# CACAATCTAGAATG-2            0
# CAAGAAGAACCAGT-3            0
# CCTAAACTATTCGG-1            0
# ATTTAGGAGCTGAT-2            0
# CGCTACACTTGCAG-2            0
# AAAGTTTGTCGATG-1            0
# CGTACAGAAGCCAT-3            0
# CTATCCCTTCTACT-1            0
# CTATTGTGAGGCGA-2            0
# CTGACAGACGAGTT-3            0
# GAAAGATGGAATAG-2            0
# ATCGTTTGCTATGG-2            0
# ATCCAGGAGCTCCT-1            0
# TTTGACTGGAATAG-3            0

# %%
# combined_obs[combined_obs['experiment'] == 'epistasis'].value_counts('condition_gears').head(30)

# %%
combined_obs_potential_collisions.loc[combined_obs_potential_collisions['condition_agrees'], 'keep'] = True
combined_obs_potential_collisions.loc[combined_obs_potential_collisions['condition_agrees'], 'source_verified'] = True

# %%
partial_collisions_resolved_barcodes = combined_obs_potential_collisions[combined_obs_potential_collisions['condition_agrees']].index
print(len(partial_collisions_resolved_barcodes))
# Out:
# 26

# %% [markdown]
# ### quick check that all cell_barcode entries match original_barcode (they should because no duplicate barcode was present in GEARS to have to make unique)

# %%
all([x == y for x,y in zip(combined_obs_potential_collisions.index, combined_obs_potential_collisions['original_barcode'])])
# Out:
# True

# %% [markdown]
# ### Check the non-matching ones, which should be 68 rows (34 cells but doubled because we get the match to each of 2 Adamson experiments it could have come from)

# %%
combined_obs_potential_collisions.loc[combined_obs_potential_collisions.index.difference(partial_collisions_resolved_barcodes)]
# Out:
#                  condition_gears cell_type dose_val  control  condition_name  \
# cell_barcode
# AAAGTTTGTCGATG-1            ctrl   K562(?)        1        1  K562(?)_ctrl_1
# AAAGTTTGTCGATG-1            ctrl   K562(?)        1        1  K562(?)_ctrl_1
# AACTCACTCTCATT-1            ctrl   K562(?)        1        1  K562(?)_ctrl_1
# AACTCACTCTCATT-1            ctrl   K562(?)        1        1  K562(?)_ctrl_1
# ACCCGTTGTGGTCA-1            ctrl   K562(?)        1        1  K562(?)_ctrl_1
# ...                          ...       ...      ...      ...             ...
# TGGGTATGTGGAAA-1            ctrl   K562(?)        1        1  K562(?)_ctrl_1
# TGTATCTGACCCAA-3            ctrl   K562(?)        1        1  K562(?)_ctrl_1
# TGTATCTGACCCAA-3            ctrl   K562(?)        1        1  K562(?)_ctrl_1
# TTTGACTGGAATAG-3            ctrl   K562(?)        1        1  K562(?)_ctrl_1
# TTTGACTGGAATAG-3            ctrl   K562(?)        1        1  K562(?)_ctrl_1
#
#                   potential_collision  original_barcode  barcode_collision  \
# cell_barcode
# AAAGTTTGTCGATG-1                 True  AAAGTTTGTCGATG-1              False
# AAAGTTTGTCGATG-1                 True  AAAGTTTGTCGATG-1              False
# AACTCACTCTCATT-1                 True  AACTCACTCTCATT-1              False
# AACTCACTCTCATT-1                 True  AACTCACTCTCATT-1              False
# ACCCGTTGTGGTCA-1                 True  ACCCGTTGTGGTCA-1              False
# ...                               ...               ...                ...
# TGGGTATGTGGAAA-1                 True  TGGGTATGTGGAAA-1              False
# TGTATCTGACCCAA-3                 True  TGTATCTGACCCAA-3              False
# TGTATCTGACCCAA-3                 True  TGTATCTGACCCAA-3              False
# TTTGACTGGAATAG-3                 True  TTTGACTGGAATAG-3              False
# TTTGACTGGAATAG-3                 True  TTTGACTGGAATAG-3              False
#
#                          guide_identity  read_count  ...  \
# cell_barcode                                         ...
# AAAGTTTGTCGATG-1           SPCS2_pDS401      1262.0  ...
# AAAGTTTGTCGATG-1  ATF6_PERK_IRE1_pMJ158       156.0  ...
# AACTCACTCTCATT-1           SLMO2_pDS433       361.0  ...
# AACTCACTCTCATT-1       ATF6_PERK_pMJ150        90.0  ...
# ACCCGTTGTGGTCA-1         DNAJC19_pDS074       988.0  ...
# ...                                 ...         ...  ...
# TGGGTATGTGGAAA-1       PERK_IRE1_pMJ154       438.0  ...
# TGTATCTGACCCAA-3            DARS_pDS495       178.0  ...
# TGTATCTGACCCAA-3       PERK_only_pMJ146       321.0  ...
# TTTGACTGGAATAG-3          SEC61G_pDS440       629.0  ...
# TTTGACTGGAATAG-3       IRE1_only_pMJ148       103.0  ...
#
#                   log1p_total_counts_ribo  pct_counts_ribo  total_counts_hb  \
# cell_barcode
# AAAGTTTGTCGATG-1                 8.621914        23.315693            372.0
# AAAGTTTGTCGATG-1                 8.995289        28.088751            340.0
# AACTCACTCTCATT-1                 8.339740        23.159060            201.0
# AACTCACTCTCATT-1                 8.425955        28.606358            281.0
# ACCCGTTGTGGTCA-1                 8.560444        23.537899            355.0
# ...                                   ...              ...              ...
# TGGGTATGTGGAAA-1                 9.094930        34.919453            197.0
# TGTATCTGACCCAA-3                 8.124743        26.928293            143.0
# TGTATCTGACCCAA-3                 9.046644        31.342072            343.0
# TTTGACTGGAATAG-3                 8.434029        26.458069            217.0
# TTTGACTGGAATAG-3                 8.563695        31.548193            155.0
#
#                   log1p_total_counts_hb pct_counts_hb  experiment  \
# cell_barcode
# AAAGTTTGTCGATG-1               5.921578      1.562500         upr
# AAAGTTTGTCGATG-1               5.831882      1.184298   epistasis
# AACTCACTCTCATT-1               5.308268      1.112033         upr
# AACTCACTCTCATT-1               5.641907      1.761645   epistasis
# ACCCGTTGTGGTCA-1               5.874931      1.600758         upr
# ...                                 ...           ...         ...
# TGGGTATGTGGAAA-1               5.288267      0.772155   epistasis
# TGTATCTGACCCAA-3               4.969813      1.140624         upr
# TGTATCTGACCCAA-3               5.840641      1.266384   epistasis
# TTTGACTGGAATAG-3               5.384495      1.248131         upr
# TTTGACTGGAATAG-3               5.049856      0.933735   epistasis
#
#                   condition_gears_harmonized  condition_agrees   keep  \
# cell_barcode
# AAAGTTTGTCGATG-1                     control             False  False
# AAAGTTTGTCGATG-1                     control             False  False
# AACTCACTCTCATT-1                     control             False  False
# AACTCACTCTCATT-1                     control             False  False
# ACCCGTTGTGGTCA-1                     control             False  False
# ...                                      ...               ...    ...
# TGGGTATGTGGAAA-1                     control             False  False
# TGTATCTGACCCAA-3                     control             False  False
# TGTATCTGACCCAA-3                     control             False  False
# TTTGACTGGAATAG-3                     control             False  False
# TTTGACTGGAATAG-3                     control             False  False
#
#                   source_verified
# cell_barcode
# AAAGTTTGTCGATG-1            False
# AAAGTTTGTCGATG-1            False
# AACTCACTCTCATT-1            False
# AACTCACTCTCATT-1            False
# ACCCGTTGTGGTCA-1            False
# ...                           ...
# TGGGTATGTGGAAA-1            False
# TGTATCTGACCCAA-3            False
# TGTATCTGACCCAA-3            False
# TTTGACTGGAATAG-3            False
# TTTGACTGGAATAG-3            False
#
# [68 rows x 37 columns]

# %% [markdown]
# ### Check if these are all control cells and, if so, could they all have come from epistasis where all the double-perturbations were relabeled control by the GEARS authors
# Even if this is the case, would not trust it and will instead label these cells as `source_verified` False.

# %%
combined_obs_potential_collisions.loc[combined_obs_potential_collisions.index.difference(partial_collisions_resolved_barcodes)].value_counts('condition_gears_harmonized')
# Out:
# condition_gears_harmonized
# control    68
# AMIGO3      0
# SOCS1       0
# SLMO2       0
# SLC39A7     0
#            ..
# GBF1        0
# FECH        0
# FARSB       0
# EIF2S1      0
# MTHFD1      0
# Name: count, Length: 88, dtype: int64

# %%
combined_obs_potential_collisions.loc[combined_obs_potential_collisions.index.difference(partial_collisions_resolved_barcodes)].groupby('original_barcode').agg(any_epistasis=pd.NamedAgg('experiment', any_epistasis)).value_counts()
# Out:
# any_epistasis
# True             31
# False             3
# Name: count, dtype: int64

# %% [markdown]
# ### Create new dataframe that collapses these pairs back down to single entries, capturing both possible Adamson sources

# %%
unresolved_potential_collisions = combined_obs_potential_collisions.loc[combined_obs_potential_collisions.index.difference(partial_collisions_resolved_barcodes)]
unresolved_potential_collisions['condition_adamson'] = unresolved_potential_collisions['condition_adamson'].astype(str)
unresolved_potential_collisions['condition_adamson'] = unresolved_potential_collisions['condition_adamson'].fillna('none')

agg = dict.fromkeys(unresolved_potential_collisions.columns.difference(['condition_adamson', 'experiment']), 'first')
agg['condition_adamson'] = lambda s: '|'.join(s)
agg['experiment'] = lambda s: '|'.join(s)

potential_collisions_replacement_rows = (
    unresolved_potential_collisions
     .groupby(unresolved_potential_collisions.index)
     .agg(agg)
)
potential_collisions_replacement_rows['keep'] = True
potential_collisions_replacement_rows['source_verified'] = False
potential_collisions_replacement_rows[columns_of_interest]
# Out:
#                   original_barcode condition_gears condition_gears_harmonized  \
# cell_barcode
# AAAGTTTGTCGATG-1  AAAGTTTGTCGATG-1            ctrl                    control
# AACTCACTCTCATT-1  AACTCACTCTCATT-1            ctrl                    control
# ACCCGTTGTGGTCA-1  ACCCGTTGTGGTCA-1            ctrl                    control
# ACTCTCCTCACACA-1  ACTCTCCTCACACA-1            ctrl                    control
# ACTGCCACTAGAGA-1  ACTGCCACTAGAGA-1            ctrl                    control
# AGGGTTTGCTCCAC-1  AGGGTTTGCTCCAC-1            ctrl                    control
# ATCCAGGAGCTCCT-1  ATCCAGGAGCTCCT-1            ctrl                    control
# ATCGTTTGCTATGG-2  ATCGTTTGCTATGG-2            ctrl                    control
# ATTTAGGAGCTGAT-2  ATTTAGGAGCTGAT-2            ctrl                    control
# CAAGAAGAACCAGT-3  CAAGAAGAACCAGT-3            ctrl                    control
# CACAATCTAGAATG-2  CACAATCTAGAATG-2            ctrl                    control
# CACGATGAGTAAAG-3  CACGATGAGTAAAG-3            ctrl                    control
# CACGCTACGACAGG-3  CACGCTACGACAGG-3            ctrl                    control
# CACTTATGCTTATC-2  CACTTATGCTTATC-2            ctrl                    control
# CATAAAACTCGTAG-2  CATAAAACTCGTAG-2            ctrl                    control
# CCTAAACTATTCGG-1  CCTAAACTATTCGG-1            ctrl                    control
# CGCTACACTTGCAG-2  CGCTACACTTGCAG-2            ctrl                    control
# CGTACAGAAGCCAT-3  CGTACAGAAGCCAT-3            ctrl                    control
# CTATCCCTTCTACT-1  CTATCCCTTCTACT-1            ctrl                    control
# CTATTGTGAGGCGA-2  CTATTGTGAGGCGA-2            ctrl                    control
# CTGACAGACGAGTT-3  CTGACAGACGAGTT-3            ctrl                    control
# GAAAGATGGAATAG-2  GAAAGATGGAATAG-2            ctrl                    control
# GGTGATACTTCTCA-1  GGTGATACTTCTCA-1            ctrl                    control
# GTGAACACTCCTGC-1  GTGAACACTCCTGC-1            ctrl                    control
# TACATCACTGACCA-3  TACATCACTGACCA-3            ctrl                    control
# TACTACTGCGTCTC-1  TACTACTGCGTCTC-1            ctrl                    control
# TAGTTGCTACCCTC-3  TAGTTGCTACCCTC-3            ctrl                    control
# TATCAGCTGAGGGT-3  TATCAGCTGAGGGT-3            ctrl                    control
# TCACCTCTCTCTAT-1  TCACCTCTCTCTAT-1            ctrl                    control
# TCAGGATGCTTCTA-3  TCAGGATGCTTCTA-3            ctrl                    control
# TCGCAGCTAACGGG-1  TCGCAGCTAACGGG-1            ctrl                    control
# TGGGTATGTGGAAA-1  TGGGTATGTGGAAA-1            ctrl                    control
# TGTATCTGACCCAA-3  TGTATCTGACCCAA-3            ctrl                    control
# TTTGACTGGAATAG-3  TTTGACTGGAATAG-3            ctrl                    control
#
#                         condition_adamson  condition_agrees       experiment
# cell_barcode
# AAAGTTTGTCGATG-1     SPCS2|ATF6_PERK_IRE1             False    upr|epistasis
# AACTCACTCTCATT-1          SLMO2|ATF6_PERK             False    upr|epistasis
# ACCCGTTGTGGTCA-1      DNAJC19|3x_neg_ctrl             False    upr|epistasis
# ACTCTCCTCACACA-1              SNAI1|STT3A             False        pilot|upr
# ACTGCCACTAGAGA-1           MARS|ATF6_only             False    upr|epistasis
# AGGGTTTGCTCCAC-1      BHLHE40|3x_neg_ctrl             False  pilot|epistasis
# ATCCAGGAGCTCCT-1        EP300|Gal4-4(mod)             False        pilot|upr
# ATCGTTTGCTATGG-2          HSPA9|ATF6_IRE1             False    upr|epistasis
# ATTTAGGAGCTGAT-2         FECH|3x_neg_ctrl             False    upr|epistasis
# CAAGAAGAACCAGT-3    Gal4-4(mod)|PERK_only             False    upr|epistasis
# CACAATCTAGAATG-2    Gal4-4(mod)|PERK_IRE1             False    upr|epistasis
# CACGATGAGTAAAG-3   IER3IP1|ATF6_PERK_IRE1             False    upr|epistasis
# CACGCTACGACAGG-3      SRPR|ATF6_PERK_IRE1             False    upr|epistasis
# CACTTATGCTTATC-2          SRP68|ATF6_IRE1             False    upr|epistasis
# CATAAAACTCGTAG-2  Gal4-4(mod)|3x_neg_ctrl             False    upr|epistasis
# CCTAAACTATTCGG-1              *|ATF6_only             False    upr|epistasis
# CGCTACACTTGCAG-2           TARS|PERK_IRE1             False    upr|epistasis
# CGTACAGAAGCCAT-3    KCTD16|ATF6_PERK_IRE1             False    upr|epistasis
# CTATCCCTTCTACT-1          EP300|ATF6_IRE1             False  pilot|epistasis
# CTATTGTGAGGCGA-2          HYOU1|ATF6_PERK             False    upr|epistasis
# CTGACAGACGAGTT-3          DHDDS|PERK_only             False    upr|epistasis
# GAAAGATGGAATAG-2          NEDD8|IRE1_only             False    upr|epistasis
# GGTGATACTTCTCA-1        HSPA5|3x_neg_ctrl             False    upr|epistasis
# GTGAACACTCCTGC-1                SNAI1|nan             False  pilot|epistasis
# TACATCACTGACCA-3        ASCC3|3x_neg_ctrl             False    upr|epistasis
# TACTACTGCGTCTC-1        DNAJC19|ATF6_only             False    upr|epistasis
# TAGTTGCTACCCTC-3    Gal4-4(mod)|ATF6_only             False    upr|epistasis
# TATCAGCTGAGGGT-3         EIF2S1|PERK_IRE1             False    upr|epistasis
# TCACCTCTCTCTAT-1              EP300|ASCC3             False        pilot|upr
# TCAGGATGCTTCTA-3           FECH|ATF6_only             False    upr|epistasis
# TCGCAGCTAACGGG-1          EP300|PERK_IRE1             False  pilot|epistasis
# TGGGTATGTGGAAA-1           QARS|PERK_IRE1             False    upr|epistasis
# TGTATCTGACCCAA-3           DARS|PERK_only             False    upr|epistasis
# TTTGACTGGAATAG-3         SEC61G|IRE1_only             False    upr|epistasis

# %% [markdown]
# ### Combine these with the rest of the potential collisions data and there should be only 60 rows marked as `keep`

# %%
potential_collisions_df = pd.concat([combined_obs_potential_collisions, potential_collisions_replacement_rows])
potential_collisions_df.value_counts('keep')
# Out:
# keep
# False    94
# True     60
# Name: count, dtype: int64

# %% [markdown]
# ## Recombine all of the merged metadata across Adamson and GEARS to create a new .obs for the GEARS version of the data

# %%
new_gears_obs = pd.concat([combined_obs_unique, combined_obs_barcode_collisions_resolved, potential_collisions_df])
new_gears_obs.value_counts('keep')
# Out:
# keep
# True     68603
# False       94
# Name: count, dtype: int64

# %% [markdown]
# Keeping the original authors' `3x_neg_ctrl` label for control cells in the epistasis experiment has been advantageous to this point as it provided a distinct label compared to control cells coming from other experiments. But now it can be harmonized to `control` like the other control cells.

# %%
new_gears_obs = new_gears_obs[new_gears_obs['keep']]
new_gears_obs = new_gears_obs.drop('keep', axis=1)
new_gears_obs['condition_adamson'] = new_gears_obs['condition_adamson'].astype(str).replace('3x_neg_ctrl', 'control')
new_gears_obs['condition_agrees'] = (new_gears_obs['condition_gears_harmonized'] == new_gears_obs['condition_adamson'])
new_gears_obs['condition_corrected'] = where(new_gears_obs['source_verified'], new_gears_obs['condition_adamson'], 'ambiguous')
new_gears_obs[columns_of_interest + ['condition_corrected']]
# Out:
#                   original_barcode condition_gears condition_gears_harmonized  \
# cell_barcode
# AAACATACACCGAT-1  AAACATACACCGAT-1      CREB1+ctrl                      CREB1
# AAACATACAGAGAT-1  AAACATACAGAGAT-1            ctrl                    control
# AAACATACCAGAAA-1  AAACATACCAGAAA-1            ctrl                    control
# AAACATACGTTGAC-1  AAACATACGTTGAC-1            ctrl                    control
# AAACATACTGTTCT-1  AAACATACTGTTCT-1            ctrl                    control
# ...                            ...             ...                        ...
# TCAGGATGCTTCTA-3  TCAGGATGCTTCTA-3            ctrl                    control
# TCGCAGCTAACGGG-1  TCGCAGCTAACGGG-1            ctrl                    control
# TGGGTATGTGGAAA-1  TGGGTATGTGGAAA-1            ctrl                    control
# TGTATCTGACCCAA-3  TGTATCTGACCCAA-3            ctrl                    control
# TTTGACTGGAATAG-3  TTTGACTGGAATAG-3            ctrl                    control
#
#                  condition_adamson  condition_agrees       experiment  \
# cell_barcode
# AAACATACACCGAT-1             CREB1              True            pilot
# AAACATACAGAGAT-1             SNAI1             False            pilot
# AAACATACCAGAAA-1           control              True            pilot
# AAACATACGTTGAC-1             EP300             False            pilot
# AAACATACTGTTCT-1           control              True            pilot
# ...                            ...               ...              ...
# TCAGGATGCTTCTA-3    FECH|ATF6_only             False    upr|epistasis
# TCGCAGCTAACGGG-1   EP300|PERK_IRE1             False  pilot|epistasis
# TGGGTATGTGGAAA-1    QARS|PERK_IRE1             False    upr|epistasis
# TGTATCTGACCCAA-3    DARS|PERK_only             False    upr|epistasis
# TTTGACTGGAATAG-3  SEC61G|IRE1_only             False    upr|epistasis
#
#                  condition_corrected
# cell_barcode
# AAACATACACCGAT-1               CREB1
# AAACATACAGAGAT-1               SNAI1
# AAACATACCAGAAA-1             control
# AAACATACGTTGAC-1               EP300
# AAACATACTGTTCT-1             control
# ...                              ...
# TCAGGATGCTTCTA-3           ambiguous
# TCGCAGCTAACGGG-1           ambiguous
# TGGGTATGTGGAAA-1           ambiguous
# TGTATCTGACCCAA-3           ambiguous
# TTTGACTGGAATAG-3           ambiguous
#
# [68603 rows x 7 columns]

# %% [markdown]
# ## sort the corrected .obs dataframe to be in the same order as the original GEARS .obs

# %%
new_gears_obs.index.is_unique
# Out:
# True

# %%
new_gears_obs = new_gears_obs.reindex(gears_original_index)
assert(all(new_gears_obs.index == gears_original_index))
print(f'Order matches? {all(new_gears_obs.index == gears_original_index)}')
# Out:
# Order matches? True

# %% [markdown]
# ### extra paranoia sanity check that should be completely unnecessary if all the indices match: do all `'condition_gears` in `new_gears_obs` match `condition` in GEARS .obs?

# %%
assert(all(gears.obs['condition'] == new_gears_obs['condition_gears']))
print(f"All conditions match? {all(gears.obs['condition'] == new_gears_obs['condition_gears'])}")
# Out:
# All conditions match? True

# %% [markdown]
# ### how many conditions agree between GEARS labels and corrected labels

# %%
new_gears_obs.value_counts('condition_agrees')
# Out:
# condition_agrees
# True     53718
# False    14885
# Name: count, dtype: int64

# %% [markdown]
# ## Replace .obs and write the corrected output file

# %%
gears.obs = new_gears_obs

# %%
gears.write(DATA_DIR.joinpath('gears_adamson_updated_metadata.h5ad'))

# %% [markdown]
# ## Assessment of differences between original GEARS annotations and metadata that has now been updated from the source GEO submission

# %%
gears.obs.value_counts('condition_corrected')
# Out:
# condition_corrected
# control           9378
# IRE1_only         1547
# ATF6_only         1542
# ATF6_PERK_IRE1    1536
# PERK_IRE1         1504
#                   ...
# CAD                242
# COPZ1              220
# PPWD1              190
# COPB1              185
# ambiguous           82
# Name: count, Length: 98, dtype: int64

# %%
gears.obs.value_counts(['experiment', 'source_verified'])
# Out:
# experiment       source_verified
# upr              True               49796
# epistasis        True               13423
# pilot            True                5302
# upr|epistasis    False                 39
# pilot|epistasis  False                 38
# pilot|upr        False                  5
# Name: count, dtype: int64

# %%
gears.obs.value_counts('condition_agrees')
# Out:
# condition_agrees
# True     53718
# False    14885
# Name: count, dtype: int64

# %%
gears.obs.value_counts(['experiment', 'condition_agrees'])
# Out:
# experiment       condition_agrees
# upr              True                47017
# epistasis        False               10315
# pilot            True                 3593
# epistasis        True                 3108
# upr              False                2779
# pilot            False                1709
# upr|epistasis    False                  39
# pilot|epistasis  False                  38
# pilot|upr        False                   5
# Name: count, dtype: int64

# %%
adamson_all.obs.loc[adamson_all.obs.index.difference(gears.obs.index)].value_counts('experiment')
# Out:
# experiment
# upr          15501
# epistasis     1497
# pilot          450
# Name: count, dtype: int64

# %%
gears[(gears.obs['condition_gears'] == 'ctrl') & (gears.obs['condition_corrected'] != 'ctrl')].obs.value_counts('experiment')
# Out:
# experiment
# epistasis          13423
# upr                 7384
# pilot               3374
# upr|epistasis         39
# pilot|epistasis       38
# pilot|upr              5
# Name: count, dtype: int64

# %%
gears[(gears.obs['condition_gears'] == 'ctrl') & (gears.obs['condition_corrected'] != 'control') & (gears.obs['experiment']== 'upr')].obs[['original_barcode', 'condition_gears', 'condition_corrected', 'guide_identity']]
# Out:
#                     original_barcode condition_gears condition_corrected  \
# cell_barcode
# AAACTTGAAACGGG-1    AAACTTGAAACGGG-1            ctrl             DNAJC19
# AAATACTGGTCGAT-1    AAATACTGGTCGAT-1            ctrl              SEC61B
# AAATTCGAATTCTC-1    AAATTCGAATTCTC-1            ctrl               ASCC3
# AACACTCTCTCCCA-1    AACACTCTCTCCCA-1            ctrl              SEC61B
# AACAGAGACACTGA-1    AACAGAGACACTGA-1            ctrl              SEC61B
# ...                              ...             ...                 ...
# TTGTACACACCTTT-10  TTGTACACACCTTT-10            ctrl               ASCC3
# TTGTAGCTCCTCCA-10  TTGTAGCTCCTCCA-10            ctrl              SEC61B
# TTTAGAGAACGTAC-10  TTTAGAGAACGTAC-10            ctrl              SEC61B
# TTTCGAACGGTGGA-10  TTTCGAACGGTGGA-10            ctrl             DNAJC19
# TTTGACTGTACGAC-10  TTTGACTGTACGAC-10            ctrl               ASCC3
#
#                    guide_identity
# cell_barcode
# AAACTTGAAACGGG-1   DNAJC19_pDS026
# AAATACTGGTCGAT-1    SEC61B_pDS033
# AAATTCGAATTCTC-1     ASCC3_pDS052
# AACACTCTCTCCCA-1    SEC61B_pDS033
# AACAGAGACACTGA-1    SEC61B_pDS033
# ...                           ...
# TTGTACACACCTTT-10    ASCC3_pDS052
# TTGTAGCTCCTCCA-10   SEC61B_pDS033
# TTTAGAGAACGTAC-10   SEC61B_pDS033
# TTTCGAACGGTGGA-10  DNAJC19_pDS026
# TTTGACTGTACGAC-10    ASCC3_pDS052
#
# [2779 rows x 4 columns]

# %%
gears[(gears.obs['condition_gears'] == 'ctrl') & (gears.obs['condition_corrected'] != 'control') & (gears.obs['experiment']== 'upr')].obs.value_counts('condition_corrected')
# Out:
# condition_corrected
# SEC61B     1000
# ASCC3       954
# DNAJC19     825
# Name: count, dtype: int64
